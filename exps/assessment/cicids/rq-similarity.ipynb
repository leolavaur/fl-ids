# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from toolbox import init, newfig

init()

SAVEDIR = (
    "/Users/leo/Workspace/phdcybersec/thesis/src/chapters/50_assessment/figures/cicids/"
)
APPENDIX_SAVEDIR = "/Users/leo/Workspace/phdcybersec/thesis/src/appendices/figures/"

# %% [markdown]
# ## Executive Summary
#
# - **RQ0**: Is the experiment sound?
# - **RQ1**: Is the behavior of poisoning attacks predictable?
# - **RQ2**: Are there hyperparameter combinations that are beneficial or detrimental in poisoning situation?
# - **RQ3**: At what point do poisoning attacks start having an impact? (proportion of poisoned data/clients)
# - **RQ4**: Can FL recover from poisoning attacks after model aggregation? How long does it take?
# - **RQ5**: Are backdoor attacks realistic in IDS context?
# - **RQ6**: Is model similarity enough to detect poisoning attacks?

# %% [markdown]
# ## RQ6: Is model similarity enough to detect poisoning attacks?
#
#
# ### Test methodology
#
# ```yaml
# partitioner: glob(iid_*)
# +datasets: nfv2/sampled/cicids
# batch_size: 512
# +epochs: 100/10x10
# +distribution: 10-0,9-1,5-5
# +target: dos,ddos,bot,bruteforce,infiltration,untargeted
# +scenario: continuous-100
# seed: 1138,421,1313,5555,6567,327,2187,1977,501,3263827
# ```
#
# - goal is to evaluate the impact of dataset partitioning on the similarity of models, and therefore the ability to detect poisoning attacks in such a context
# - hyperparameters are fixed as the "best" ones from RQ2
# - $\alpha=100$
# - 3 benign-attackers distributions
#   - 0% attacker to see the impact of the partitioning performance
#   - 10% attackers (ie, one client) to see if his model is identifiable
#   - 50% attackers to see if similar attacks are detectable
# - all attacks to see if there are differences + untargeted

# %%
from eiffel.analysis.metrics import choices, display_choices

display_choices(choices("similarity/results/"))
# Out:
# <style>table td, table th, table tr {text-align:left !important;}</style><table><tr><th>Key</th><th>Values</th></tr><tr><td>datasets</td><td>nfv2_sampled_cicids</td></tr><tr><td>distribution</td><td>5-5, 9-1, 10-0</td></tr><tr><td>epochs</td><td>100_10x10</td></tr><tr><td>scenario</td><td>continuous-100</td></tr><tr><td>target</td><td>untargeted, infiltration, dos, bruteforce, ddos, bot</td></tr><tr><td>batch_size</td><td>512</td></tr><tr><td>partitioner</td><td>iid_drop_1, kmeans_drop_1, iid_drop_2, kmeans_drop_2, iid_keep_1, iid_full, kmeans_full, kmeans_keep_1</td></tr><tr><td>seed</td><td>1138, 421, 5555, 2187, 1313, 327, 6567, 501, 3263827, 1977</td></tr></table>

# %% [markdown]
# ### Partitioning effect on data distribution
#
# - make a dataframe with the the sample numbers in each partitioning scheme
#   - columns are the partitioning schemes
#   - rows are tuples "{partition}-{label}"

# %%
import json
import re
from pathlib import Path

import pandas as pd
from eiffel.analysis.metrics import search_results

SEED = 1138

paths = search_results(
    "similarity/results/",
    scenario="continuous-100",
    target="untargeted",
    datasets=".*cicids",
    distribution="10-0",
    seed=SEED,
)

part_re = r"partitioner=(\w+),"

stats_df = pd.DataFrame()

for path in paths:
    res = re.search(part_re, path)
    assert res is not None
    partitioner = res.group(1)

    idx = []
    samples = []

    stats = next(iter(json.loads((Path(path) / "stats.json").read_text()).values()))
    for k, v in stats.items():
        part = "_".join(k.split("_")[1:])
        train_stats: dict = v.get("train")
        assert train_stats is not None

        for label in [
            "Benign",
            "Bot",
            "DDoS",
            "DoS",
            "Brute Force",
            "Infilteration",
            "injection",
        ]:
            idx.append(f"{part}_{label}")
            n = train_stats.get(label)
            if n is None:
                n = 0
            samples.append(n)

        s = pd.Series(samples, index=idx, name=partitioner).astype(int)

    stats_df = pd.concat([stats_df, s], axis=1)

stats_df
# Out:
#                         iid_drop_1  iid_drop_2  iid_full  iid_keep_1  \
# benign_0_Benign              70432       70432     70432       70432
# benign_0_Bot                   616         616       616           0
# benign_0_DDoS                 5887           0      5887           0
# benign_0_DoS                     0           0      2051        2051
# benign_0_Brute Force           522         522       522           0
# ...                            ...         ...       ...         ...
# benign_9_DDoS                 5886        5886      5886           0
# benign_9_DoS                  2051           0      2051           0
# benign_9_Brute Force             0           0       522         522
# benign_9_Infilteration         492         492       492           0
# benign_9_injection               1           1         1           0
#
#                         kmeans_drop_1  kmeans_drop_2  kmeans_full  \
# benign_0_Benign                 38441          38441        38441
# benign_0_Bot                      616            616          616
# benign_0_DDoS                    5887              0         5887
# benign_0_DoS                        0              0         2051
# benign_0_Brute Force              522            522          522
# ...                               ...            ...          ...
# benign_9_DDoS                    5886           5886         5886
# benign_9_DoS                     2051              0         2051
# benign_9_Brute Force                0              0          522
# benign_9_Infilteration            492            492          492
# benign_9_injection                  1              1            1
#
#                         kmeans_keep_1
# benign_0_Benign                 38441
# benign_0_Bot                        0
# benign_0_DDoS                       0
# benign_0_DoS                     2051
# benign_0_Brute Force                0
# ...                               ...
# benign_9_DDoS                       0
# benign_9_DoS                        0
# benign_9_Brute Force              522
# benign_9_Infilteration              0
# benign_9_injection                  0
#
# [70 rows x 8 columns]

# %% [markdown]
# ### Impact on the benign scenario

# %%
from functools import partial

import numpy as np
from eiffel.analysis.metrics import load_df, search_results

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    target="untargeted",
    datasets=".*cicids",
    distribution="10-0",
)

fig = newfig(width=0.45, format=4 / 3)
ax = fig.add_subplot(111)

for i, partitioner in enumerate(
    [
        "iid_full",
        "iid_drop_1",
        "iid_drop_2",
        "iid_keep_1",
        "kmeans_full",
        "kmeans_drop_1",
        "kmeans_drop_2",
        "kmeans_keep_1",
    ]
):
    data = load_df(searchfn(partitioner=partitioner), dotpath="global.f1", attr="fit")

    ax.plot(data.mean(axis=0), label=r"\texttt{" f"{partitioner}" "}")


ax.grid(axis="y", linestyle="--", alpha=0.5)
ax.set_ylabel("Accuracy", loc="top")
ax.set_yticks(np.arange(0, 1.1, 0.2))
ax.set_xticks(np.arange(0, 11, 1))

lgd = fig.legend(ncol=1, loc="right", bbox_to_anchor=(1.5, 0.5))

fig.savefig(
    SAVEDIR + "niid-perf.pdf",
    bbox_extra_artists=(lgd,),
    bbox_inches="tight",
)

# %%
from functools import partial

import numpy as np
from eiffel.analysis.metrics import search_results
from sklearn.decomposition import PCA

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    target="untargeted",
    datasets=".*cicids",
    distribution="10-0",
)

grads_df = pd.DataFrame()
seed_re = r"seed=(\d+)(?:,.*)?"

for partitioner in [
    "iid_full",
    "iid_drop_1",
    "iid_drop_2",
    "iid_keep_1",
    "kmeans_full",
    "kmeans_drop_1",
    "kmeans_drop_2",
    "kmeans_keep_1",
]:
    for path in searchfn(partitioner=partitioner):
        res = re.search(seed_re, path)
        assert res is not None
        seed = res.group(1)
        part_grads_dfs: list[pd.DataFrame] = [
            pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")
        ]
        part_grads_df = pd.concat(part_grads_dfs, axis=0)
        part_grads_df["Partitioner"] = partitioner
        part_grads_df["Seed"] = seed
        grads_df = pd.concat([grads_df, part_grads_df], axis=0, ignore_index=True)

grads_array = np.array(grads_df["Gradients"].tolist())
grads_array = (grads_array - grads_array.mean(axis=0)) / grads_array.std(axis=0)
pca = PCA(n_components=2)
grads_pca = pca.fit_transform(grads_array)

grads_df["PCA1"] = grads_pca[:, 0]
grads_df["PCA2"] = grads_pca[:, 1]

grads_df["Client"] = grads_df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))

# %%
from typing import cast

from matplotlib import colormaps
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import NullLocator

cmap = colormaps["tab10"]

fig = newfig(2 / 1)
axs = fig.subplots(2, 4, sharex=True, sharey=True)
assert type(axs) == np.ndarray

df = grads_df  # [(grads_df["Seed"] == "1138") & (grads_df["Round"] > 1)]

levels, categories = pd.factorize(df["Client"])
df["Color"] = [cmap(i) for i in levels]
handles = [Patch(color=cmap(i), label=c) for i, c in enumerate(categories)]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(r"\texttt{%s}" % partitioner)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[
        (df["Partitioner"] == partitioner)
        & (grads_df["Seed"] == "1138")
        & (grads_df["Round"] > 1)
    ]

    ax.scatter(data["PCA1"], data["PCA2"], s=2, c=data["Color"])

handles = sorted(handles, key=lambda x: cast(str, x.get_label()))
lgd = fig.legend(
    handles=handles, ncol=5, loc="lower center", bbox_to_anchor=(0.5, -0.15)
)
fig.suptitle("Gradients in 2D, colored by client (seed=1138)")
fig.savefig(
    APPENDIX_SAVEDIR + "cicids-grads-per-client.pdf",
    bbox_extra_artists=(lgd,),
    bbox_inches="tight",
)

# %%
from typing import cast

from matplotlib import colormaps
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import NullLocator

cmap = colormaps["tab10"]

fig = newfig(2 / 1)
axs = fig.subplots(2, 4, sharex=True, sharey=True)
assert type(axs) == np.ndarray

df = grads_df  # [(grads_df["Seed"] == "1138") & (grads_df["Round"] > 1)]

levels, categories = pd.factorize(df["Round"])
df["Color"] = [cmap(i) for i in levels]
handles = [Patch(color=cmap(i), label=c) for i, c in enumerate(categories)]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(r"\texttt{%s}" % partitioner)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[
        (df["Partitioner"] == partitioner) & (grads_df["Seed"] == "1138")
        # & (grads_df["Round"] > 1)
    ]

    ax.scatter(data["PCA1"], data["PCA2"], s=2, c=data["Color"])

handles = sorted(handles, key=lambda x: int(cast(str, x.get_label())))
lgd = fig.legend(
    handles=handles, ncol=5, loc="lower center", bbox_to_anchor=(0.5, -0.15)
)
fig.suptitle("Gradients in 2D, colored by round (seed=1138)")
fig.savefig(
    APPENDIX_SAVEDIR + "cicids-grads-per-round.pdf",
    bbox_extra_artists=(lgd,),
    bbox_inches="tight",
)

# %% [markdown]
# ### Identifiability of one lone attacker

# %%
import itertools
from functools import partial
from pathlib import Path

import pandas as pd
from eiffel.analysis.metrics import search_results

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    datasets=".*cicids",
    distribution="9-1",
)

grads_df = pd.DataFrame()

for target, partitioner, seed in itertools.product(
    [
        "untargeted",
        "dos",
        "ddos",
        "bot",
        "bruteforce",
        "infiltration",
        # "injection" has been removed due to its low representation
    ],
    [
        "iid_full",
        "iid_drop_1",
        "iid_drop_2",
        "iid_keep_1",
        "kmeans_full",
        "kmeans_drop_1",
        "kmeans_drop_2",
        "kmeans_keep_1",
    ],
    [1138, 421, 1313, 5555, 6567, 327, 2187, 1977, 501, 3263827],
):
    print(f"Loading: {target}, {partitioner}, {seed}")

    paths = searchfn(partitioner=partitioner, target=target, seed=seed)
    assert len(paths) == 1
    path = paths[0]
    part_grads_dfs: list[pd.DataFrame] = [
        pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")
    ]
    assert part_grads_dfs[0].shape[0] == 10  # ten client per partition
    assert len(part_grads_dfs) == 10  # ten rounds

    part_grads_df = pd.concat(part_grads_dfs, axis=0, ignore_index=True)
    part_grads_df["Partitioner"] = partitioner
    part_grads_df["Target"] = target
    part_grads_df["Seed"] = seed

    grads_df = pd.concat([grads_df, part_grads_df], axis=0, ignore_index=True)

print("Loaded all gradients")

grads_df["Client"] = grads_df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))
# Out:
# Loading: untargeted, iid_full, 1138
# Loading: untargeted, iid_full, 421
# Loading: untargeted, iid_full, 1313
# Loading: untargeted, iid_full, 5555
# Loading: untargeted, iid_full, 6567
# Loading: untargeted, iid_full, 327
# Loading: untargeted, iid_full, 2187
# Loading: untargeted, iid_full, 1977
# Loading: untargeted, iid_full, 501
# Loading: untargeted, iid_full, 3263827
# Loading: untargeted, iid_drop_1, 1138
# Loading: untargeted, iid_drop_1, 421
# Loading: untargeted, iid_drop_1, 1313
# Loading: untargeted, iid_drop_1, 5555
# Loading: untargeted, iid_drop_1, 6567
# Loading: untargeted, iid_drop_1, 327
# Loading: untargeted, iid_drop_1, 2187
# Loading: untargeted, iid_drop_1, 1977
# Loading: untargeted, iid_drop_1, 501
# Loading: untargeted, iid_drop_1, 3263827
# Loading: untargeted, iid_drop_2, 1138
# Loading: untargeted, iid_drop_2, 421
# Loading: untargeted, iid_drop_2, 1313
# Loading: untargeted, iid_drop_2, 5555
# Loading: untargeted, iid_drop_2, 6567
# Loading: untargeted, iid_drop_2, 327
# Loading: untargeted, iid_drop_2, 2187
# Loading: untargeted, iid_drop_2, 1977
# Loading: untargeted, iid_drop_2, 501
# Loading: untargeted, iid_drop_2, 3263827
# Loading: untargeted, iid_keep_1, 1138
# Loading: untargeted, iid_keep_1, 421
# Loading: untargeted, iid_keep_1, 1313
# Loading: untargeted, iid_keep_1, 5555
# Loading: untargeted, iid_keep_1, 6567
# Loading: untargeted, iid_keep_1, 327
# Loading: untargeted, iid_keep_1, 2187
# Loading: untargeted, iid_keep_1, 1977
# Loading: untargeted, iid_keep_1, 501
# Loading: untargeted, iid_keep_1, 3263827
# Loading: untargeted, kmeans_full, 1138
# Loading: untargeted, kmeans_full, 421
# Loading: untargeted, kmeans_full, 1313
# Loading: untargeted, kmeans_full, 5555
# Loading: untargeted, kmeans_full, 6567
# Loading: untargeted, kmeans_full, 327
# Loading: untargeted, kmeans_full, 2187
# Loading: untargeted, kmeans_full, 1977
# Loading: untargeted, kmeans_full, 501
# Loading: untargeted, kmeans_full, 3263827
# Loading: untargeted, kmeans_drop_1, 1138
# Loading: untargeted, kmeans_drop_1, 421
# Loading: untargeted, kmeans_drop_1, 1313
# Loading: untargeted, kmeans_drop_1, 5555
# Loading: untargeted, kmeans_drop_1, 6567
# Loading: untargeted, kmeans_drop_1, 327
# Loading: untargeted, kmeans_drop_1, 2187
# Loading: untargeted, kmeans_drop_1, 1977
# Loading: untargeted, kmeans_drop_1, 501
# Loading: untargeted, kmeans_drop_1, 3263827
# Loading: untargeted, kmeans_drop_2, 1138
# Loading: untargeted, kmeans_drop_2, 421
# Loading: untargeted, kmeans_drop_2, 1313
# Loading: untargeted, kmeans_drop_2, 5555
# Loading: untargeted, kmeans_drop_2, 6567
# Loading: untargeted, kmeans_drop_2, 327
# Loading: untargeted, kmeans_drop_2, 2187
# Loading: untargeted, kmeans_drop_2, 1977
# Loading: untargeted, kmeans_drop_2, 501
# Loading: untargeted, kmeans_drop_2, 3263827
# Loading: untargeted, kmeans_keep_1, 1138
# Loading: untargeted, kmeans_keep_1, 421
# Loading: untargeted, kmeans_keep_1, 1313
# Loading: untargeted, kmeans_keep_1, 5555
# Loading: untargeted, kmeans_keep_1, 6567
# Loading: untargeted, kmeans_keep_1, 327
# Loading: untargeted, kmeans_keep_1, 2187
# Loading: untargeted, kmeans_keep_1, 1977
# Loading: untargeted, kmeans_keep_1, 501
# Loading: untargeted, kmeans_keep_1, 3263827
# Loading: dos, iid_full, 1138
# Loading: dos, iid_full, 421
# Loading: dos, iid_full, 1313
# Loading: dos, iid_full, 5555
# Loading: dos, iid_full, 6567
# Loading: dos, iid_full, 327
# Loading: dos, iid_full, 2187
# Loading: dos, iid_full, 1977
# Loading: dos, iid_full, 501
# Loading: dos, iid_full, 3263827
# Loading: dos, iid_drop_1, 1138
# Loading: dos, iid_drop_1, 421
# Loading: dos, iid_drop_1, 1313
# Loading: dos, iid_drop_1, 5555
# Loading: dos, iid_drop_1, 6567
# Loading: dos, iid_drop_1, 327
# Loading: dos, iid_drop_1, 2187
# Loading: dos, iid_drop_1, 1977
# Loading: dos, iid_drop_1, 501
# Loading: dos, iid_drop_1, 3263827
# Loading: dos, iid_drop_2, 1138
# Loading: dos, iid_drop_2, 421
# Loading: dos, iid_drop_2, 1313
# Loading: dos, iid_drop_2, 5555
# Loading: dos, iid_drop_2, 6567
# Loading: dos, iid_drop_2, 327
# Loading: dos, iid_drop_2, 2187
# Loading: dos, iid_drop_2, 1977
# Loading: dos, iid_drop_2, 501
# Loading: dos, iid_drop_2, 3263827
# Loading: dos, iid_keep_1, 1138
# Loading: dos, iid_keep_1, 421
# Loading: dos, iid_keep_1, 1313
# Loading: dos, iid_keep_1, 5555
# Loading: dos, iid_keep_1, 6567
# Loading: dos, iid_keep_1, 327
# Loading: dos, iid_keep_1, 2187
# Loading: dos, iid_keep_1, 1977
# Loading: dos, iid_keep_1, 501
# Loading: dos, iid_keep_1, 3263827
# Loading: dos, kmeans_full, 1138
# Loading: dos, kmeans_full, 421
# Loading: dos, kmeans_full, 1313
# Loading: dos, kmeans_full, 5555
# Loading: dos, kmeans_full, 6567
# Loading: dos, kmeans_full, 327
# Loading: dos, kmeans_full, 2187
# Loading: dos, kmeans_full, 1977
# Loading: dos, kmeans_full, 501
# Loading: dos, kmeans_full, 3263827
# Loading: dos, kmeans_drop_1, 1138
# Loading: dos, kmeans_drop_1, 421
# Loading: dos, kmeans_drop_1, 1313
# Loading: dos, kmeans_drop_1, 5555
# Loading: dos, kmeans_drop_1, 6567
# Loading: dos, kmeans_drop_1, 327
# Loading: dos, kmeans_drop_1, 2187
# Loading: dos, kmeans_drop_1, 1977
# Loading: dos, kmeans_drop_1, 501
# Loading: dos, kmeans_drop_1, 3263827
# Loading: dos, kmeans_drop_2, 1138
# Loading: dos, kmeans_drop_2, 421
# Loading: dos, kmeans_drop_2, 1313
# Loading: dos, kmeans_drop_2, 5555
# Loading: dos, kmeans_drop_2, 6567
# Loading: dos, kmeans_drop_2, 327
# Loading: dos, kmeans_drop_2, 2187
# Loading: dos, kmeans_drop_2, 1977
# Loading: dos, kmeans_drop_2, 501
# Loading: dos, kmeans_drop_2, 3263827
# Loading: dos, kmeans_keep_1, 1138
# Loading: dos, kmeans_keep_1, 421
# Loading: dos, kmeans_keep_1, 1313
# Loading: dos, kmeans_keep_1, 5555
# Loading: dos, kmeans_keep_1, 6567
# Loading: dos, kmeans_keep_1, 327
# Loading: dos, kmeans_keep_1, 2187
# Loading: dos, kmeans_keep_1, 1977
# Loading: dos, kmeans_keep_1, 501
# Loading: dos, kmeans_keep_1, 3263827
# Loading: ddos, iid_full, 1138
# Loading: ddos, iid_full, 421
# Loading: ddos, iid_full, 1313
# Loading: ddos, iid_full, 5555
# Loading: ddos, iid_full, 6567
# Loading: ddos, iid_full, 327
# Loading: ddos, iid_full, 2187
# Loading: ddos, iid_full, 1977
# Loading: ddos, iid_full, 501
# Loading: ddos, iid_full, 3263827
# Loading: ddos, iid_drop_1, 1138
# Loading: ddos, iid_drop_1, 421
# Loading: ddos, iid_drop_1, 1313
# Loading: ddos, iid_drop_1, 5555
# Loading: ddos, iid_drop_1, 6567
# Loading: ddos, iid_drop_1, 327
# Loading: ddos, iid_drop_1, 2187
# Loading: ddos, iid_drop_1, 1977
# Loading: ddos, iid_drop_1, 501
# Loading: ddos, iid_drop_1, 3263827
# Loading: ddos, iid_drop_2, 1138
# Loading: ddos, iid_drop_2, 421
# Loading: ddos, iid_drop_2, 1313
# Loading: ddos, iid_drop_2, 5555
# Loading: ddos, iid_drop_2, 6567
# Loading: ddos, iid_drop_2, 327
# Loading: ddos, iid_drop_2, 2187
# Loading: ddos, iid_drop_2, 1977
# Loading: ddos, iid_drop_2, 501
# Loading: ddos, iid_drop_2, 3263827
# Loading: ddos, iid_keep_1, 1138
# Loading: ddos, iid_keep_1, 421
# Loading: ddos, iid_keep_1, 1313
# Loading: ddos, iid_keep_1, 5555
# Loading: ddos, iid_keep_1, 6567
# Loading: ddos, iid_keep_1, 327
# Loading: ddos, iid_keep_1, 2187
# Loading: ddos, iid_keep_1, 1977
# Loading: ddos, iid_keep_1, 501
# Loading: ddos, iid_keep_1, 3263827
# Loading: ddos, kmeans_full, 1138
# Loading: ddos, kmeans_full, 421
# Loading: ddos, kmeans_full, 1313
# Loading: ddos, kmeans_full, 5555
# Loading: ddos, kmeans_full, 6567
# Loading: ddos, kmeans_full, 327
# Loading: ddos, kmeans_full, 2187
# Loading: ddos, kmeans_full, 1977
# Loading: ddos, kmeans_full, 501
# Loading: ddos, kmeans_full, 3263827
# Loading: ddos, kmeans_drop_1, 1138
# Loading: ddos, kmeans_drop_1, 421
# Loading: ddos, kmeans_drop_1, 1313
# Loading: ddos, kmeans_drop_1, 5555
# Loading: ddos, kmeans_drop_1, 6567
# Loading: ddos, kmeans_drop_1, 327
# Loading: ddos, kmeans_drop_1, 2187
# Loading: ddos, kmeans_drop_1, 1977
# Loading: ddos, kmeans_drop_1, 501
# Loading: ddos, kmeans_drop_1, 3263827
# Loading: ddos, kmeans_drop_2, 1138
# Loading: ddos, kmeans_drop_2, 421
# Loading: ddos, kmeans_drop_2, 1313
# Loading: ddos, kmeans_drop_2, 5555
# Loading: ddos, kmeans_drop_2, 6567
# Loading: ddos, kmeans_drop_2, 327
# Loading: ddos, kmeans_drop_2, 2187
# Loading: ddos, kmeans_drop_2, 1977
# Loading: ddos, kmeans_drop_2, 501
# Loading: ddos, kmeans_drop_2, 3263827
# Loading: ddos, kmeans_keep_1, 1138
# Loading: ddos, kmeans_keep_1, 421
# Loading: ddos, kmeans_keep_1, 1313
# Loading: ddos, kmeans_keep_1, 5555
# Loading: ddos, kmeans_keep_1, 6567
# Loading: ddos, kmeans_keep_1, 327
# Loading: ddos, kmeans_keep_1, 2187
# Loading: ddos, kmeans_keep_1, 1977
# Loading: ddos, kmeans_keep_1, 501
# Loading: ddos, kmeans_keep_1, 3263827
# Loading: bot, iid_full, 1138
# Loading: bot, iid_full, 421
# Loading: bot, iid_full, 1313
# Loading: bot, iid_full, 5555
# Loading: bot, iid_full, 6567
# Loading: bot, iid_full, 327
# Loading: bot, iid_full, 2187
# Loading: bot, iid_full, 1977
# Loading: bot, iid_full, 501
# Loading: bot, iid_full, 3263827
# Loading: bot, iid_drop_1, 1138
# Loading: bot, iid_drop_1, 421
# Loading: bot, iid_drop_1, 1313
# Loading: bot, iid_drop_1, 5555
# Loading: bot, iid_drop_1, 6567
# Loading: bot, iid_drop_1, 327
# Loading: bot, iid_drop_1, 2187
# Loading: bot, iid_drop_1, 1977
# Loading: bot, iid_drop_1, 501
# Loading: bot, iid_drop_1, 3263827
# Loading: bot, iid_drop_2, 1138
# Loading: bot, iid_drop_2, 421
# Loading: bot, iid_drop_2, 1313
# Loading: bot, iid_drop_2, 5555
# Loading: bot, iid_drop_2, 6567
# Loading: bot, iid_drop_2, 327
# Loading: bot, iid_drop_2, 2187
# Loading: bot, iid_drop_2, 1977
# Loading: bot, iid_drop_2, 501
# Loading: bot, iid_drop_2, 3263827
# Loading: bot, iid_keep_1, 1138
# Loading: bot, iid_keep_1, 421
# Loading: bot, iid_keep_1, 1313
# Loading: bot, iid_keep_1, 5555
# Loading: bot, iid_keep_1, 6567
# Loading: bot, iid_keep_1, 327
# Loading: bot, iid_keep_1, 2187
# Loading: bot, iid_keep_1, 1977
# Loading: bot, iid_keep_1, 501
# Loading: bot, iid_keep_1, 3263827
# Loading: bot, kmeans_full, 1138
# Loading: bot, kmeans_full, 421
# Loading: bot, kmeans_full, 1313
# Loading: bot, kmeans_full, 5555
# Loading: bot, kmeans_full, 6567
# Loading: bot, kmeans_full, 327
# Loading: bot, kmeans_full, 2187
# Loading: bot, kmeans_full, 1977
# Loading: bot, kmeans_full, 501
# Loading: bot, kmeans_full, 3263827
# Loading: bot, kmeans_drop_1, 1138
# Loading: bot, kmeans_drop_1, 421
# Loading: bot, kmeans_drop_1, 1313
# Loading: bot, kmeans_drop_1, 5555
# Loading: bot, kmeans_drop_1, 6567
# Loading: bot, kmeans_drop_1, 327
# Loading: bot, kmeans_drop_1, 2187
# Loading: bot, kmeans_drop_1, 1977
# Loading: bot, kmeans_drop_1, 501
# Loading: bot, kmeans_drop_1, 3263827
# Loading: bot, kmeans_drop_2, 1138
# Loading: bot, kmeans_drop_2, 421
# Loading: bot, kmeans_drop_2, 1313
# Loading: bot, kmeans_drop_2, 5555
# Loading: bot, kmeans_drop_2, 6567
# Loading: bot, kmeans_drop_2, 327
# Loading: bot, kmeans_drop_2, 2187
# Loading: bot, kmeans_drop_2, 1977
# Loading: bot, kmeans_drop_2, 501
# Loading: bot, kmeans_drop_2, 3263827
# Loading: bot, kmeans_keep_1, 1138
# Loading: bot, kmeans_keep_1, 421
# Loading: bot, kmeans_keep_1, 1313
# Loading: bot, kmeans_keep_1, 5555
# Loading: bot, kmeans_keep_1, 6567
# Loading: bot, kmeans_keep_1, 327
# Loading: bot, kmeans_keep_1, 2187
# Loading: bot, kmeans_keep_1, 1977
# Loading: bot, kmeans_keep_1, 501
# Loading: bot, kmeans_keep_1, 3263827
# Loading: bruteforce, iid_full, 1138
# Loading: bruteforce, iid_full, 421
# Loading: bruteforce, iid_full, 1313
# Loading: bruteforce, iid_full, 5555
# Loading: bruteforce, iid_full, 6567
# Loading: bruteforce, iid_full, 327
# Loading: bruteforce, iid_full, 2187
# Loading: bruteforce, iid_full, 1977
# Loading: bruteforce, iid_full, 501
# Loading: bruteforce, iid_full, 3263827
# Loading: bruteforce, iid_drop_1, 1138
# Loading: bruteforce, iid_drop_1, 421
# Loading: bruteforce, iid_drop_1, 1313
# Loading: bruteforce, iid_drop_1, 5555
# Loading: bruteforce, iid_drop_1, 6567
# Loading: bruteforce, iid_drop_1, 327
# Loading: bruteforce, iid_drop_1, 2187
# Loading: bruteforce, iid_drop_1, 1977
# Loading: bruteforce, iid_drop_1, 501
# Loading: bruteforce, iid_drop_1, 3263827
# Loading: bruteforce, iid_drop_2, 1138
# Loading: bruteforce, iid_drop_2, 421
# Loading: bruteforce, iid_drop_2, 1313
# Loading: bruteforce, iid_drop_2, 5555
# Loading: bruteforce, iid_drop_2, 6567
# Loading: bruteforce, iid_drop_2, 327
# Loading: bruteforce, iid_drop_2, 2187
# Loading: bruteforce, iid_drop_2, 1977
# Loading: bruteforce, iid_drop_2, 501
# Loading: bruteforce, iid_drop_2, 3263827
# Loading: bruteforce, iid_keep_1, 1138
# Loading: bruteforce, iid_keep_1, 421
# Loading: bruteforce, iid_keep_1, 1313
# Loading: bruteforce, iid_keep_1, 5555
# Loading: bruteforce, iid_keep_1, 6567
# Loading: bruteforce, iid_keep_1, 327
# Loading: bruteforce, iid_keep_1, 2187
# Loading: bruteforce, iid_keep_1, 1977
# Loading: bruteforce, iid_keep_1, 501
# Loading: bruteforce, iid_keep_1, 3263827
# Loading: bruteforce, kmeans_full, 1138
# Loading: bruteforce, kmeans_full, 421
# Loading: bruteforce, kmeans_full, 1313
# Loading: bruteforce, kmeans_full, 5555
# Loading: bruteforce, kmeans_full, 6567
# Loading: bruteforce, kmeans_full, 327
# Loading: bruteforce, kmeans_full, 2187
# Loading: bruteforce, kmeans_full, 1977
# Loading: bruteforce, kmeans_full, 501
# Loading: bruteforce, kmeans_full, 3263827
# Loading: bruteforce, kmeans_drop_1, 1138
# Loading: bruteforce, kmeans_drop_1, 421
# Loading: bruteforce, kmeans_drop_1, 1313
# Loading: bruteforce, kmeans_drop_1, 5555
# Loading: bruteforce, kmeans_drop_1, 6567
# Loading: bruteforce, kmeans_drop_1, 327
# Loading: bruteforce, kmeans_drop_1, 2187
# Loading: bruteforce, kmeans_drop_1, 1977
# Loading: bruteforce, kmeans_drop_1, 501
# Loading: bruteforce, kmeans_drop_1, 3263827
# Loading: bruteforce, kmeans_drop_2, 1138
# Loading: bruteforce, kmeans_drop_2, 421
# Loading: bruteforce, kmeans_drop_2, 1313
# Loading: bruteforce, kmeans_drop_2, 5555
# Loading: bruteforce, kmeans_drop_2, 6567
# Loading: bruteforce, kmeans_drop_2, 327
# Loading: bruteforce, kmeans_drop_2, 2187
# Loading: bruteforce, kmeans_drop_2, 1977
# Loading: bruteforce, kmeans_drop_2, 501
# Loading: bruteforce, kmeans_drop_2, 3263827
# Loading: bruteforce, kmeans_keep_1, 1138
# Loading: bruteforce, kmeans_keep_1, 421
# Loading: bruteforce, kmeans_keep_1, 1313
# Loading: bruteforce, kmeans_keep_1, 5555
# Loading: bruteforce, kmeans_keep_1, 6567
# Loading: bruteforce, kmeans_keep_1, 327
# Loading: bruteforce, kmeans_keep_1, 2187
# Loading: bruteforce, kmeans_keep_1, 1977
# Loading: bruteforce, kmeans_keep_1, 501
# Loading: bruteforce, kmeans_keep_1, 3263827
# Loading: infiltration, iid_full, 1138
# Loading: infiltration, iid_full, 421
# Loading: infiltration, iid_full, 1313
# Loading: infiltration, iid_full, 5555
# Loading: infiltration, iid_full, 6567
# Loading: infiltration, iid_full, 327
# Loading: infiltration, iid_full, 2187
# Loading: infiltration, iid_full, 1977
# Loading: infiltration, iid_full, 501
# Loading: infiltration, iid_full, 3263827
# Loading: infiltration, iid_drop_1, 1138
# Loading: infiltration, iid_drop_1, 421
# Loading: infiltration, iid_drop_1, 1313
# Loading: infiltration, iid_drop_1, 5555
# Loading: infiltration, iid_drop_1, 6567
# Loading: infiltration, iid_drop_1, 327
# Loading: infiltration, iid_drop_1, 2187
# Loading: infiltration, iid_drop_1, 1977
# Loading: infiltration, iid_drop_1, 501
# Loading: infiltration, iid_drop_1, 3263827
# Loading: infiltration, iid_drop_2, 1138
# Loading: infiltration, iid_drop_2, 421
# Loading: infiltration, iid_drop_2, 1313
# Loading: infiltration, iid_drop_2, 5555
# Loading: infiltration, iid_drop_2, 6567
# Loading: infiltration, iid_drop_2, 327
# Loading: infiltration, iid_drop_2, 2187
# Loading: infiltration, iid_drop_2, 1977
# Loading: infiltration, iid_drop_2, 501
# Loading: infiltration, iid_drop_2, 3263827
# Loading: infiltration, iid_keep_1, 1138
# Loading: infiltration, iid_keep_1, 421
# Loading: infiltration, iid_keep_1, 1313
# Loading: infiltration, iid_keep_1, 5555
# Loading: infiltration, iid_keep_1, 6567
# Loading: infiltration, iid_keep_1, 327
# Loading: infiltration, iid_keep_1, 2187
# Loading: infiltration, iid_keep_1, 1977
# Loading: infiltration, iid_keep_1, 501
# Loading: infiltration, iid_keep_1, 3263827
# Loading: infiltration, kmeans_full, 1138
# Loading: infiltration, kmeans_full, 421
# Loading: infiltration, kmeans_full, 1313
# Loading: infiltration, kmeans_full, 5555
# Loading: infiltration, kmeans_full, 6567
# Loading: infiltration, kmeans_full, 327
# Loading: infiltration, kmeans_full, 2187
# Loading: infiltration, kmeans_full, 1977
# Loading: infiltration, kmeans_full, 501
# Loading: infiltration, kmeans_full, 3263827
# Loading: infiltration, kmeans_drop_1, 1138
# Loading: infiltration, kmeans_drop_1, 421
# Loading: infiltration, kmeans_drop_1, 1313
# Loading: infiltration, kmeans_drop_1, 5555
# Loading: infiltration, kmeans_drop_1, 6567
# Loading: infiltration, kmeans_drop_1, 327
# Loading: infiltration, kmeans_drop_1, 2187
# Loading: infiltration, kmeans_drop_1, 1977
# Loading: infiltration, kmeans_drop_1, 501
# Loading: infiltration, kmeans_drop_1, 3263827
# Loading: infiltration, kmeans_drop_2, 1138
# Loading: infiltration, kmeans_drop_2, 421
# Loading: infiltration, kmeans_drop_2, 1313
# Loading: infiltration, kmeans_drop_2, 5555
# Loading: infiltration, kmeans_drop_2, 6567
# Loading: infiltration, kmeans_drop_2, 327
# Loading: infiltration, kmeans_drop_2, 2187
# Loading: infiltration, kmeans_drop_2, 1977
# Loading: infiltration, kmeans_drop_2, 501
# Loading: infiltration, kmeans_drop_2, 3263827
# Loading: infiltration, kmeans_keep_1, 1138
# Loading: infiltration, kmeans_keep_1, 421
# Loading: infiltration, kmeans_keep_1, 1313
# Loading: infiltration, kmeans_keep_1, 5555
# Loading: infiltration, kmeans_keep_1, 6567
# Loading: infiltration, kmeans_keep_1, 327
# Loading: infiltration, kmeans_keep_1, 2187
# Loading: infiltration, kmeans_keep_1, 1977
# Loading: infiltration, kmeans_keep_1, 501
# Loading: infiltration, kmeans_keep_1, 3263827
# Loaded all gradients

# %% [markdown]
# ### PCA

# %%
from matplotlib.axes import Axes
from matplotlib.ticker import NullLocator
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import StandardScaler

fig = newfig(2 / 1, width=0.8)
axs = fig.subplots(2, 4, sharex=True, sharey=True)
assert type(axs) == np.ndarray

df = grads_df

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    ax: Axes
    # figure setup
    ax.set_title(r"\texttt{%s}" % partitioner)
    ax.set_box_aspect(1)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[
        (df["Partitioner"] == partitioner)
        & (df["Target"] == "untargeted")
        & (df["Seed"] == 1138)
        # & (df["Round"] > 1)
        & (df["Round"] == 10)
    ]

    grads_array = np.array(data["Gradients"].tolist())
    grads_array = StandardScaler().fit_transform(grads_array)
    grads_pca = PCA(n_components=2).fit_transform(grads_array)

    benign = grads_pca[data["Client"].str.contains("benign")]
    ax.scatter(benign[:, 0], benign[:, 1], s=8, c="blue", label="Benign")

    malicious = grads_pca[~data["Client"].str.contains("benign")]
    ax.scatter(
        malicious[:, 0], malicious[:, 1], s=14, marker="x", c="red", label="Malicious"
    )

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles, ncol=5, loc="lower center", bbox_to_anchor=(0.5, -0.12)
)
fig.savefig(
    SAVEDIR + "similarity-untargeted-single.pdf",
    bbox_extra_artists=(lgd,),
    bbox_inches="tight",
)

# %%
from matplotlib import pyplot as plt
from matplotlib.axes import Axes
from matplotlib.ticker import NullLocator
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import StandardScaler

fig = newfig(2 / 1, width=0.8)
axs = fig.subplots(2, 4, sharex=True, sharey=True)
assert type(axs) == np.ndarray

df = grads_df


for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    ax: Axes
    # figure setup
    ax.set_title(r"\texttt{%s}" % partitioner)
    ax.set_box_aspect(1)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[
        (df["Partitioner"] == partitioner)
        & (df["Target"] == "untargeted")
        & (df["Seed"] == 1138)
        # & (df["Round"] > 1)
        & (df["Round"] == 10)
    ]

    grads_array = np.array(data["Gradients"].tolist())
    grads_array = StandardScaler().fit_transform(grads_array)
    grads_pca = PCA(n_components=2).fit_transform(grads_array)
    data["PCA1"] = grads_pca[:, 0]
    data["PCA2"] = grads_pca[:, 1]

    benign = data[data["Client"].str.contains("benign")]
    ax.scatter(
        benign["PCA1"], benign["PCA2"], s=8, color="blue", label="Benign", alpha=0.5
    )

    malicious = data[~data["Client"].str.contains("benign")]
    for label, c, m in zip(
        ["dos", "ddos", "bot", "bruteforce", "infiltration"],
        ["red", "green", "purple", "orange", "yellow"],
        ["x", "+", "*", "h", "D"],
    ):
        target = malicious[malicious["Target"] == label]
        ax.scatter(
            malicious["PCA1"],
            malicious["PCA2"],
            s=14,
            marker=m,
            color=c,
            label=label,
            alpha=0.5,
        )

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles,
    labels=labels,
    ncol=6,
    loc="lower center",
    bbox_to_anchor=(0.5, -0.1),
)
# Out:
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA1"] = grads_pca[:, 0]
# /var/folders/6v/8wy9dm6938n6yt0_hkf53crr0000gn/T/ipykernel_2791/586654890.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PCA2"] = grads_pca[:, 1]

# %% [markdown]
# ### Detectability of similar attacks

# %%
import itertools
from functools import partial
from pathlib import Path

import pandas as pd
from eiffel.analysis.metrics import search_results

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    datasets=".*cicids",
    distribution="5-5",
)

grads_df = pd.DataFrame()

for target, partitioner, seed in itertools.product(
    [
        "untargeted",
        "dos",
        "ddos",
        "bot",
        "bruteforce",
        "infiltration",
        # "injection" has been removed due to its low representation
    ],
    [
        "iid_full",
        "iid_drop_1",
        "iid_drop_2",
        "iid_keep_1",
        "kmeans_full",
        "kmeans_drop_1",
        "kmeans_drop_2",
        "kmeans_keep_1",
    ],
    [1138, 421, 1313, 5555, 6567, 327, 2187, 1977, 501, 3263827],
):
    print(f"Loading: {target}, {partitioner}, {seed}")

    paths = searchfn(partitioner=partitioner, target=target, seed=seed)
    assert len(paths) == 1
    path = paths[0]
    part_grads_dfs: list[pd.DataFrame] = [
        pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")
    ]
    assert part_grads_dfs[0].shape[0] == 10  # ten client per partition
    assert len(part_grads_dfs) == 10  # ten clients

    part_grads_df = pd.concat(part_grads_dfs, axis=0, ignore_index=True)
    part_grads_df["Partitioner"] = partitioner
    part_grads_df["Target"] = target
    part_grads_df["Seed"] = seed

    grads_df = pd.concat([grads_df, part_grads_df], axis=0, ignore_index=True)

print("Loaded all gradients")
# Out:
# Loading: untargeted, iid_full, 1138
# Loading: untargeted, iid_full, 421
# Loading: untargeted, iid_full, 1313
# Loading: untargeted, iid_full, 5555
# Loading: untargeted, iid_full, 6567
# Loading: untargeted, iid_full, 327
# Loading: untargeted, iid_full, 2187
# Loading: untargeted, iid_full, 1977
# Loading: untargeted, iid_full, 501
# Loading: untargeted, iid_full, 3263827
# Loading: untargeted, iid_drop_1, 1138
# Loading: untargeted, iid_drop_1, 421
# Loading: untargeted, iid_drop_1, 1313
# Loading: untargeted, iid_drop_1, 5555
# Loading: untargeted, iid_drop_1, 6567
# Loading: untargeted, iid_drop_1, 327
# Loading: untargeted, iid_drop_1, 2187
# Loading: untargeted, iid_drop_1, 1977
# Loading: untargeted, iid_drop_1, 501
# Loading: untargeted, iid_drop_1, 3263827
# Loading: untargeted, iid_drop_2, 1138
# Loading: untargeted, iid_drop_2, 421
# Loading: untargeted, iid_drop_2, 1313
# Loading: untargeted, iid_drop_2, 5555
# Loading: untargeted, iid_drop_2, 6567
# Loading: untargeted, iid_drop_2, 327
# Loading: untargeted, iid_drop_2, 2187
# Loading: untargeted, iid_drop_2, 1977
# Loading: untargeted, iid_drop_2, 501
# Loading: untargeted, iid_drop_2, 3263827
# Loading: untargeted, iid_keep_1, 1138
# Loading: untargeted, iid_keep_1, 421
# Loading: untargeted, iid_keep_1, 1313
# Loading: untargeted, iid_keep_1, 5555
# Loading: untargeted, iid_keep_1, 6567
# Loading: untargeted, iid_keep_1, 327
# Loading: untargeted, iid_keep_1, 2187
# Loading: untargeted, iid_keep_1, 1977
# Loading: untargeted, iid_keep_1, 501
# Loading: untargeted, iid_keep_1, 3263827
# Loading: untargeted, kmeans_full, 1138
# Loading: untargeted, kmeans_full, 421
# Loading: untargeted, kmeans_full, 1313
# Loading: untargeted, kmeans_full, 5555
# Loading: untargeted, kmeans_full, 6567
# Loading: untargeted, kmeans_full, 327
# Loading: untargeted, kmeans_full, 2187
# Loading: untargeted, kmeans_full, 1977
# Loading: untargeted, kmeans_full, 501
# Loading: untargeted, kmeans_full, 3263827
# Loading: untargeted, kmeans_drop_1, 1138
# Loading: untargeted, kmeans_drop_1, 421
# Loading: untargeted, kmeans_drop_1, 1313
# Loading: untargeted, kmeans_drop_1, 5555
# Loading: untargeted, kmeans_drop_1, 6567
# Loading: untargeted, kmeans_drop_1, 327
# Loading: untargeted, kmeans_drop_1, 2187
# Loading: untargeted, kmeans_drop_1, 1977
# Loading: untargeted, kmeans_drop_1, 501
# Loading: untargeted, kmeans_drop_1, 3263827
# Loading: untargeted, kmeans_drop_2, 1138
# Loading: untargeted, kmeans_drop_2, 421
# Loading: untargeted, kmeans_drop_2, 1313
# Loading: untargeted, kmeans_drop_2, 5555
# Loading: untargeted, kmeans_drop_2, 6567
# Loading: untargeted, kmeans_drop_2, 327
# Loading: untargeted, kmeans_drop_2, 2187
# Loading: untargeted, kmeans_drop_2, 1977
# Loading: untargeted, kmeans_drop_2, 501
# Loading: untargeted, kmeans_drop_2, 3263827
# Loading: untargeted, kmeans_keep_1, 1138
# Loading: untargeted, kmeans_keep_1, 421
# Loading: untargeted, kmeans_keep_1, 1313
# Loading: untargeted, kmeans_keep_1, 5555
# Loading: untargeted, kmeans_keep_1, 6567
# Loading: untargeted, kmeans_keep_1, 327
# Loading: untargeted, kmeans_keep_1, 2187
# Loading: untargeted, kmeans_keep_1, 1977
# Loading: untargeted, kmeans_keep_1, 501
# Loading: untargeted, kmeans_keep_1, 3263827
# Loading: dos, iid_full, 1138
# Loading: dos, iid_full, 421
# Loading: dos, iid_full, 1313
# Loading: dos, iid_full, 5555
# Loading: dos, iid_full, 6567
# Loading: dos, iid_full, 327
# Loading: dos, iid_full, 2187
# Loading: dos, iid_full, 1977
# Loading: dos, iid_full, 501
# Loading: dos, iid_full, 3263827
# Loading: dos, iid_drop_1, 1138
# Loading: dos, iid_drop_1, 421
# Loading: dos, iid_drop_1, 1313
# Loading: dos, iid_drop_1, 5555
# Loading: dos, iid_drop_1, 6567
# Loading: dos, iid_drop_1, 327
# Loading: dos, iid_drop_1, 2187
# Loading: dos, iid_drop_1, 1977
# Loading: dos, iid_drop_1, 501
# Loading: dos, iid_drop_1, 3263827
# Loading: dos, iid_drop_2, 1138
# Loading: dos, iid_drop_2, 421
# Loading: dos, iid_drop_2, 1313
# Loading: dos, iid_drop_2, 5555
# Loading: dos, iid_drop_2, 6567
# Loading: dos, iid_drop_2, 327
# Loading: dos, iid_drop_2, 2187
# Loading: dos, iid_drop_2, 1977
# Loading: dos, iid_drop_2, 501
# Loading: dos, iid_drop_2, 3263827
# Loading: dos, iid_keep_1, 1138
# Loading: dos, iid_keep_1, 421
# Loading: dos, iid_keep_1, 1313
# Loading: dos, iid_keep_1, 5555
# Loading: dos, iid_keep_1, 6567
# Loading: dos, iid_keep_1, 327
# Loading: dos, iid_keep_1, 2187
# Loading: dos, iid_keep_1, 1977
# Loading: dos, iid_keep_1, 501
# Loading: dos, iid_keep_1, 3263827
# Loading: dos, kmeans_full, 1138
# Loading: dos, kmeans_full, 421
# Loading: dos, kmeans_full, 1313
# Loading: dos, kmeans_full, 5555
# Loading: dos, kmeans_full, 6567
# Loading: dos, kmeans_full, 327
# Loading: dos, kmeans_full, 2187
# Loading: dos, kmeans_full, 1977
# Loading: dos, kmeans_full, 501
# Loading: dos, kmeans_full, 3263827
# Loading: dos, kmeans_drop_1, 1138
# Loading: dos, kmeans_drop_1, 421
# Loading: dos, kmeans_drop_1, 1313
# Loading: dos, kmeans_drop_1, 5555
# Loading: dos, kmeans_drop_1, 6567
# Loading: dos, kmeans_drop_1, 327
# Loading: dos, kmeans_drop_1, 2187
# Loading: dos, kmeans_drop_1, 1977
# Loading: dos, kmeans_drop_1, 501
# Loading: dos, kmeans_drop_1, 3263827
# Loading: dos, kmeans_drop_2, 1138
# Loading: dos, kmeans_drop_2, 421
# Loading: dos, kmeans_drop_2, 1313
# Loading: dos, kmeans_drop_2, 5555
# Loading: dos, kmeans_drop_2, 6567
# Loading: dos, kmeans_drop_2, 327
# Loading: dos, kmeans_drop_2, 2187
# Loading: dos, kmeans_drop_2, 1977
# Loading: dos, kmeans_drop_2, 501
# Loading: dos, kmeans_drop_2, 3263827
# Loading: dos, kmeans_keep_1, 1138
# Loading: dos, kmeans_keep_1, 421
# Loading: dos, kmeans_keep_1, 1313
# Loading: dos, kmeans_keep_1, 5555
# Loading: dos, kmeans_keep_1, 6567
# Loading: dos, kmeans_keep_1, 327
# Loading: dos, kmeans_keep_1, 2187
# Loading: dos, kmeans_keep_1, 1977
# Loading: dos, kmeans_keep_1, 501
# Loading: dos, kmeans_keep_1, 3263827
# Loading: ddos, iid_full, 1138
# Loading: ddos, iid_full, 421
# Loading: ddos, iid_full, 1313
# Loading: ddos, iid_full, 5555
# Loading: ddos, iid_full, 6567
# Loading: ddos, iid_full, 327
# Loading: ddos, iid_full, 2187
# Loading: ddos, iid_full, 1977
# Loading: ddos, iid_full, 501
# Loading: ddos, iid_full, 3263827
# Loading: ddos, iid_drop_1, 1138
# Loading: ddos, iid_drop_1, 421
# Loading: ddos, iid_drop_1, 1313
# Loading: ddos, iid_drop_1, 5555
# Loading: ddos, iid_drop_1, 6567
# Loading: ddos, iid_drop_1, 327
# Loading: ddos, iid_drop_1, 2187
# Loading: ddos, iid_drop_1, 1977
# Loading: ddos, iid_drop_1, 501
# Loading: ddos, iid_drop_1, 3263827
# Loading: ddos, iid_drop_2, 1138
# Loading: ddos, iid_drop_2, 421
# Loading: ddos, iid_drop_2, 1313
# Loading: ddos, iid_drop_2, 5555
# Loading: ddos, iid_drop_2, 6567
# Loading: ddos, iid_drop_2, 327
# Loading: ddos, iid_drop_2, 2187
# Loading: ddos, iid_drop_2, 1977
# Loading: ddos, iid_drop_2, 501
# Loading: ddos, iid_drop_2, 3263827
# Loading: ddos, iid_keep_1, 1138
# Loading: ddos, iid_keep_1, 421
# Loading: ddos, iid_keep_1, 1313
# Loading: ddos, iid_keep_1, 5555
# Loading: ddos, iid_keep_1, 6567
# Loading: ddos, iid_keep_1, 327
# Loading: ddos, iid_keep_1, 2187
# Loading: ddos, iid_keep_1, 1977
# Loading: ddos, iid_keep_1, 501
# Loading: ddos, iid_keep_1, 3263827
# Loading: ddos, kmeans_full, 1138
# Loading: ddos, kmeans_full, 421
# Loading: ddos, kmeans_full, 1313
# Loading: ddos, kmeans_full, 5555
# Loading: ddos, kmeans_full, 6567
# Loading: ddos, kmeans_full, 327
# Loading: ddos, kmeans_full, 2187
# Loading: ddos, kmeans_full, 1977
# Loading: ddos, kmeans_full, 501
# Loading: ddos, kmeans_full, 3263827
# Loading: ddos, kmeans_drop_1, 1138
# Loading: ddos, kmeans_drop_1, 421
# Loading: ddos, kmeans_drop_1, 1313
# Loading: ddos, kmeans_drop_1, 5555
# Loading: ddos, kmeans_drop_1, 6567
# Loading: ddos, kmeans_drop_1, 327
# Loading: ddos, kmeans_drop_1, 2187
# Loading: ddos, kmeans_drop_1, 1977
# Loading: ddos, kmeans_drop_1, 501
# Loading: ddos, kmeans_drop_1, 3263827
# Loading: ddos, kmeans_drop_2, 1138
# Loading: ddos, kmeans_drop_2, 421
# Loading: ddos, kmeans_drop_2, 1313
# Loading: ddos, kmeans_drop_2, 5555
# Loading: ddos, kmeans_drop_2, 6567
# Loading: ddos, kmeans_drop_2, 327
# Loading: ddos, kmeans_drop_2, 2187
# Loading: ddos, kmeans_drop_2, 1977
# Loading: ddos, kmeans_drop_2, 501
# Loading: ddos, kmeans_drop_2, 3263827
# Loading: ddos, kmeans_keep_1, 1138
# Loading: ddos, kmeans_keep_1, 421
# Loading: ddos, kmeans_keep_1, 1313
# Loading: ddos, kmeans_keep_1, 5555
# Loading: ddos, kmeans_keep_1, 6567
# Loading: ddos, kmeans_keep_1, 327
# Loading: ddos, kmeans_keep_1, 2187
# Loading: ddos, kmeans_keep_1, 1977
# Loading: ddos, kmeans_keep_1, 501
# Loading: ddos, kmeans_keep_1, 3263827
# Loading: bot, iid_full, 1138
# Loading: bot, iid_full, 421
# Loading: bot, iid_full, 1313
# Loading: bot, iid_full, 5555
# Loading: bot, iid_full, 6567
# Loading: bot, iid_full, 327
# Loading: bot, iid_full, 2187
# Loading: bot, iid_full, 1977
# Loading: bot, iid_full, 501
# Loading: bot, iid_full, 3263827
# Loading: bot, iid_drop_1, 1138
# Loading: bot, iid_drop_1, 421
# Loading: bot, iid_drop_1, 1313
# Loading: bot, iid_drop_1, 5555
# Loading: bot, iid_drop_1, 6567
# Loading: bot, iid_drop_1, 327
# Loading: bot, iid_drop_1, 2187
# Loading: bot, iid_drop_1, 1977
# Loading: bot, iid_drop_1, 501
# Loading: bot, iid_drop_1, 3263827
# Loading: bot, iid_drop_2, 1138
# Loading: bot, iid_drop_2, 421
# Loading: bot, iid_drop_2, 1313
# Loading: bot, iid_drop_2, 5555
# Loading: bot, iid_drop_2, 6567
# Loading: bot, iid_drop_2, 327
# Loading: bot, iid_drop_2, 2187
# Loading: bot, iid_drop_2, 1977
# Loading: bot, iid_drop_2, 501
# Loading: bot, iid_drop_2, 3263827
# Loading: bot, iid_keep_1, 1138
# Loading: bot, iid_keep_1, 421
# Loading: bot, iid_keep_1, 1313
# Loading: bot, iid_keep_1, 5555
# Loading: bot, iid_keep_1, 6567
# Loading: bot, iid_keep_1, 327
# Loading: bot, iid_keep_1, 2187
# Loading: bot, iid_keep_1, 1977
# Loading: bot, iid_keep_1, 501
# Loading: bot, iid_keep_1, 3263827
# Loading: bot, kmeans_full, 1138
# Loading: bot, kmeans_full, 421
# Loading: bot, kmeans_full, 1313
# Loading: bot, kmeans_full, 5555
# Loading: bot, kmeans_full, 6567
# Loading: bot, kmeans_full, 327
# Loading: bot, kmeans_full, 2187
# Loading: bot, kmeans_full, 1977
# Loading: bot, kmeans_full, 501
# Loading: bot, kmeans_full, 3263827
# Loading: bot, kmeans_drop_1, 1138
# Loading: bot, kmeans_drop_1, 421
# Loading: bot, kmeans_drop_1, 1313
# Loading: bot, kmeans_drop_1, 5555
# Loading: bot, kmeans_drop_1, 6567
# Loading: bot, kmeans_drop_1, 327
# Loading: bot, kmeans_drop_1, 2187
# Loading: bot, kmeans_drop_1, 1977
# Loading: bot, kmeans_drop_1, 501
# Loading: bot, kmeans_drop_1, 3263827
# Loading: bot, kmeans_drop_2, 1138
# Loading: bot, kmeans_drop_2, 421
# Loading: bot, kmeans_drop_2, 1313
# Loading: bot, kmeans_drop_2, 5555
# Loading: bot, kmeans_drop_2, 6567
# Loading: bot, kmeans_drop_2, 327
# Loading: bot, kmeans_drop_2, 2187
# Loading: bot, kmeans_drop_2, 1977
# Loading: bot, kmeans_drop_2, 501
# Loading: bot, kmeans_drop_2, 3263827
# Loading: bot, kmeans_keep_1, 1138
# Loading: bot, kmeans_keep_1, 421
# Loading: bot, kmeans_keep_1, 1313
# Loading: bot, kmeans_keep_1, 5555
# Loading: bot, kmeans_keep_1, 6567
# Loading: bot, kmeans_keep_1, 327
# Loading: bot, kmeans_keep_1, 2187
# Loading: bot, kmeans_keep_1, 1977
# Loading: bot, kmeans_keep_1, 501
# Loading: bot, kmeans_keep_1, 3263827
# Loading: bruteforce, iid_full, 1138
# Loading: bruteforce, iid_full, 421
# Loading: bruteforce, iid_full, 1313
# Loading: bruteforce, iid_full, 5555
# Loading: bruteforce, iid_full, 6567
# Loading: bruteforce, iid_full, 327
# Loading: bruteforce, iid_full, 2187
# Loading: bruteforce, iid_full, 1977
# Loading: bruteforce, iid_full, 501
# Loading: bruteforce, iid_full, 3263827
# Loading: bruteforce, iid_drop_1, 1138
# Loading: bruteforce, iid_drop_1, 421
# Loading: bruteforce, iid_drop_1, 1313
# Loading: bruteforce, iid_drop_1, 5555
# Loading: bruteforce, iid_drop_1, 6567
# Loading: bruteforce, iid_drop_1, 327
# Loading: bruteforce, iid_drop_1, 2187
# Loading: bruteforce, iid_drop_1, 1977
# Loading: bruteforce, iid_drop_1, 501
# Loading: bruteforce, iid_drop_1, 3263827
# Loading: bruteforce, iid_drop_2, 1138
# Loading: bruteforce, iid_drop_2, 421
# Loading: bruteforce, iid_drop_2, 1313
# Loading: bruteforce, iid_drop_2, 5555
# Loading: bruteforce, iid_drop_2, 6567
# Loading: bruteforce, iid_drop_2, 327
# Loading: bruteforce, iid_drop_2, 2187
# Loading: bruteforce, iid_drop_2, 1977
# Loading: bruteforce, iid_drop_2, 501
# Loading: bruteforce, iid_drop_2, 3263827
# Loading: bruteforce, iid_keep_1, 1138
# Loading: bruteforce, iid_keep_1, 421
# Loading: bruteforce, iid_keep_1, 1313
# Loading: bruteforce, iid_keep_1, 5555
# Loading: bruteforce, iid_keep_1, 6567
# Loading: bruteforce, iid_keep_1, 327
# Loading: bruteforce, iid_keep_1, 2187
# Loading: bruteforce, iid_keep_1, 1977
# Loading: bruteforce, iid_keep_1, 501
# Loading: bruteforce, iid_keep_1, 3263827
# Loading: bruteforce, kmeans_full, 1138
# Loading: bruteforce, kmeans_full, 421
# Loading: bruteforce, kmeans_full, 1313
# Loading: bruteforce, kmeans_full, 5555
# Loading: bruteforce, kmeans_full, 6567
# Loading: bruteforce, kmeans_full, 327
# Loading: bruteforce, kmeans_full, 2187
# Loading: bruteforce, kmeans_full, 1977
# Loading: bruteforce, kmeans_full, 501
# Loading: bruteforce, kmeans_full, 3263827
# Loading: bruteforce, kmeans_drop_1, 1138
# Loading: bruteforce, kmeans_drop_1, 421
# Loading: bruteforce, kmeans_drop_1, 1313
# Loading: bruteforce, kmeans_drop_1, 5555
# Loading: bruteforce, kmeans_drop_1, 6567
# Loading: bruteforce, kmeans_drop_1, 327
# Loading: bruteforce, kmeans_drop_1, 2187
# Loading: bruteforce, kmeans_drop_1, 1977
# Loading: bruteforce, kmeans_drop_1, 501
# Loading: bruteforce, kmeans_drop_1, 3263827
# Loading: bruteforce, kmeans_drop_2, 1138
# Loading: bruteforce, kmeans_drop_2, 421
# Loading: bruteforce, kmeans_drop_2, 1313
# Loading: bruteforce, kmeans_drop_2, 5555
# Loading: bruteforce, kmeans_drop_2, 6567
# Loading: bruteforce, kmeans_drop_2, 327
# Loading: bruteforce, kmeans_drop_2, 2187
# Loading: bruteforce, kmeans_drop_2, 1977
# Loading: bruteforce, kmeans_drop_2, 501
# Loading: bruteforce, kmeans_drop_2, 3263827
# Loading: bruteforce, kmeans_keep_1, 1138
# Loading: bruteforce, kmeans_keep_1, 421
# Loading: bruteforce, kmeans_keep_1, 1313
# Loading: bruteforce, kmeans_keep_1, 5555
# Loading: bruteforce, kmeans_keep_1, 6567
# Loading: bruteforce, kmeans_keep_1, 327
# Loading: bruteforce, kmeans_keep_1, 2187
# Loading: bruteforce, kmeans_keep_1, 1977
# Loading: bruteforce, kmeans_keep_1, 501
# Loading: bruteforce, kmeans_keep_1, 3263827
# Loading: infiltration, iid_full, 1138
# Loading: infiltration, iid_full, 421
# Loading: infiltration, iid_full, 1313
# Loading: infiltration, iid_full, 5555
# Loading: infiltration, iid_full, 6567
# Loading: infiltration, iid_full, 327
# Loading: infiltration, iid_full, 2187
# Loading: infiltration, iid_full, 1977
# Loading: infiltration, iid_full, 501
# Loading: infiltration, iid_full, 3263827
# Loading: infiltration, iid_drop_1, 1138
# Loading: infiltration, iid_drop_1, 421
# Loading: infiltration, iid_drop_1, 1313
# Loading: infiltration, iid_drop_1, 5555
# Loading: infiltration, iid_drop_1, 6567
# Loading: infiltration, iid_drop_1, 327
# Loading: infiltration, iid_drop_1, 2187
# Loading: infiltration, iid_drop_1, 1977
# Loading: infiltration, iid_drop_1, 501
# Loading: infiltration, iid_drop_1, 3263827
# Loading: infiltration, iid_drop_2, 1138
# Loading: infiltration, iid_drop_2, 421
# Loading: infiltration, iid_drop_2, 1313
# Loading: infiltration, iid_drop_2, 5555
# Loading: infiltration, iid_drop_2, 6567
# Loading: infiltration, iid_drop_2, 327
# Loading: infiltration, iid_drop_2, 2187
# Loading: infiltration, iid_drop_2, 1977
# Loading: infiltration, iid_drop_2, 501
# Loading: infiltration, iid_drop_2, 3263827
# Loading: infiltration, iid_keep_1, 1138
# Loading: infiltration, iid_keep_1, 421
# Loading: infiltration, iid_keep_1, 1313
# Loading: infiltration, iid_keep_1, 5555
# Loading: infiltration, iid_keep_1, 6567
# Loading: infiltration, iid_keep_1, 327
# Loading: infiltration, iid_keep_1, 2187
# Loading: infiltration, iid_keep_1, 1977
# Loading: infiltration, iid_keep_1, 501
# Loading: infiltration, iid_keep_1, 3263827
# Loading: infiltration, kmeans_full, 1138
# Loading: infiltration, kmeans_full, 421
# Loading: infiltration, kmeans_full, 1313
# Loading: infiltration, kmeans_full, 5555
# Loading: infiltration, kmeans_full, 6567
# Loading: infiltration, kmeans_full, 327
# Loading: infiltration, kmeans_full, 2187
# Loading: infiltration, kmeans_full, 1977
# Loading: infiltration, kmeans_full, 501
# Loading: infiltration, kmeans_full, 3263827
# Loading: infiltration, kmeans_drop_1, 1138
# Loading: infiltration, kmeans_drop_1, 421
# Loading: infiltration, kmeans_drop_1, 1313
# Loading: infiltration, kmeans_drop_1, 5555
# Loading: infiltration, kmeans_drop_1, 6567
# Loading: infiltration, kmeans_drop_1, 327
# Loading: infiltration, kmeans_drop_1, 2187
# Loading: infiltration, kmeans_drop_1, 1977
# Loading: infiltration, kmeans_drop_1, 501
# Loading: infiltration, kmeans_drop_1, 3263827
# Loading: infiltration, kmeans_drop_2, 1138
# Loading: infiltration, kmeans_drop_2, 421
# Loading: infiltration, kmeans_drop_2, 1313
# Loading: infiltration, kmeans_drop_2, 5555
# Loading: infiltration, kmeans_drop_2, 6567
# Loading: infiltration, kmeans_drop_2, 327
# Loading: infiltration, kmeans_drop_2, 2187
# Loading: infiltration, kmeans_drop_2, 1977
# Loading: infiltration, kmeans_drop_2, 501
# Loading: infiltration, kmeans_drop_2, 3263827
# Loading: infiltration, kmeans_keep_1, 1138
# Loading: infiltration, kmeans_keep_1, 421
# Loading: infiltration, kmeans_keep_1, 1313
# Loading: infiltration, kmeans_keep_1, 5555
# Loading: infiltration, kmeans_keep_1, 6567
# Loading: infiltration, kmeans_keep_1, 327
# Loading: infiltration, kmeans_keep_1, 2187
# Loading: infiltration, kmeans_keep_1, 1977
# Loading: infiltration, kmeans_keep_1, 501
# Loading: infiltration, kmeans_keep_1, 3263827
# Loaded all gradients

# %%
from matplotlib.axes import Axes
from matplotlib.ticker import NullLocator
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import StandardScaler

fig = newfig(2 / 1, width=0.8)
axs = fig.subplots(2, 4, sharex=True, sharey=True)
assert type(axs) == np.ndarray

df = grads_df

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    ax: Axes
    # figure setup
    ax.set_title(r"\texttt{%s}" % partitioner)
    ax.set_box_aspect(1)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[
        (df["Partitioner"] == partitioner)
        & (df["Target"] == "untargeted")
        & (df["Seed"] == 1138)
        # & (df["Round"] > 1)
        & (df["Round"] == 10)
    ]

    grads_array = np.array(data["Gradients"].tolist())
    grads_array = StandardScaler().fit_transform(grads_array)
    grads_pca = PCA(n_components=2).fit_transform(grads_array)

    benign = grads_pca[data["Client"].str.contains("benign")]
    ax.scatter(benign[:, 0], benign[:, 1], s=8, c="blue", label="Benign")

    malicious = grads_pca[~data["Client"].str.contains("benign")]
    ax.scatter(
        malicious[:, 0], malicious[:, 1], s=14, marker="x", c="red", label="Malicious"
    )

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles, ncol=5, loc="lower center", bbox_to_anchor=(0.5, -0.12)
)
fig.savefig(
    SAVEDIR + "similarity-untargeted-colluding.pdf",
    bbox_extra_artists=(lgd,),
    bbox_inches="tight",
)

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import NullLocator

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

df = grads_df[
    (grads_df["Target"] != "untargeted")
    # & (grads_df["Round"] == 10)
    & (grads_df["Seed"] == 1138)
]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[df["Partitioner"] == partitioner]

    benign = data[data["Client"].str.contains("benign")]
    ax.scatter(
        benign["PCA1"], benign["PCA2"], s=1, color="blue", label="Benign", alpha=0.5
    )

    malicious = data[~data["Client"].str.contains("benign")]
    for label, c in zip(
        ["dos", "ddos", "bot", "bruteforce", "infiltration"],
        ["red", "green", "purple", "orange", "yellow"],
    ):
        target = malicious[malicious["Target"] == label]
        ax.scatter(
            malicious["PCA1"], malicious["PCA2"], s=1, color=c, label=label, alpha=0.5
        )

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles,
    labels=labels,
    ncol=6,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.1),
)
fig.suptitle("Gradients in 2D, colored by malicious target")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 7
#       1 from matplotlib import pyplot as plt
#       2 from matplotlib.ticker import NullLocator
#       4 fig, axs = plt.subplots(
#       5     2,
#       6     4,
# ----> 7     figsize=figsize(1, 0.5, two_column=True),
#       8     constrained_layout=True,
#       9     sharex=True,
#      10     sharey=True,
#      11 )
#      13 df = grads_df[
#      14     (grads_df["Target"] != "untargeted")
#      15     # & (grads_df["Round"] == 10)
#      16     & (grads_df["Seed"] == 1138)
#      17 ]
#      19 for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
#      20     # figure setup
#
# NameError: name 'figsize' is not defined

# %% [markdown]
# ## Testing cosine similarity
#
# - https://www.kaggle.com/code/karimsaieh/pca-principal-component-analysis-without-sklearn

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as LA
import pandas as pd
from eiffel.analysis.metrics import search_results
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

paths = search_results(
    "similarity/results/",
    scenario="continuous-100",
    datasets=".*cicids",
    distribution="5-5",
    partitioner="kmeans_full",
    target="dos",
    seed=1138,
)

path = paths[0]

dfs: list[pd.DataFrame] = [pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")]
df = pd.concat(dfs, axis=0, ignore_index=True)
df["Client"] = df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))

df = df[df["Round"] == 10]
grads = np.array(df["Gradients"].to_list())

fig, axs = plt.subplots(1, 2, figsize=figsize(2, 1), constrained_layout=True)
ax_sim, ax_pca = axs

# Projection using a cosine similarity matrix

grads = (grads - grads.mean(axis=1)[:, None]) / grads.std(axis=1)[:, None]

M = 1 - cosine_similarity(grads)

vals, vecs = LA.eig(M)
explained = vals / vals.sum() * 100
pc1 = vecs[:, 0]
pc2 = vecs[:, 1]

colors = ["blue" if "benign" in client else "red" for client in df["Client"]]


for i, grad in enumerate(grads):
    ax_sim.scatter(pc1[i], pc2[i], color=colors[i])

ax_sim.set_xlabel(rf"PC1 ({explained[0]:.2f}\%)")
ax_sim.set_ylabel(rf"PC2 ({explained[1]:.2f}\%)")
ax_sim.set_title("Cosine similarity", pad=-35)

# Projection using PCA

pca = PCA(n_components=2)
pca_grads = pca.fit_transform(grads)

for i, grad in enumerate(pca_grads):
    ax_pca.scatter(grad[0], grad[1], color=colors[i])

explained = pca.explained_variance_ratio_ * 100
ax_pca.set_xlabel(rf"PC1 ({explained[0]:.2f}\%)")
ax_pca.set_ylabel(rf"PC2 ({explained[1]:.2f}\%)")
ax_pca.set_title("PCA", pad=-35)
# Out:
# Text(0.5, 0.0, 'PCA')

# %%
from pathlib import Path

import numpy.linalg as LA
import pandas as pd
from eiffel.analysis.metrics import search_results
from sklearn.metrics.pairwise import cosine_similarity

paths = search_results(
    "similarity/results/",
    scenario="continuous-100",
    datasets=".*cicids",
    distribution="5-5",
    partitioner="kmeans_full",
    target="dos",
    seed=1138,
)

path = paths[0]

dfs: list[pd.DataFrame] = [pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")]
df = pd.concat(dfs, axis=0, ignore_index=True)
df["Client"] = df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))

df = df[df["Round"] == 10]
grads = np.array(df["Gradients"].to_list())

fig = plt.figure(figsize=figsize(1, 1), constrained_layout=True)
ax = fig.add_subplot(projection="3d")

# Projection using a cosine similarity matrix

grads = (grads - grads.mean(axis=1)[:, None]) / grads.std(axis=1)[:, None]

M = 1 - cosine_similarity(grads)

vals, vecs = LA.eig(M)
explained = vals / vals.sum() * 100
pc1 = vecs[:, 0]
pc2 = vecs[:, 1]
pc3 = vecs[:, 2]

colors = ["blue" if "benign" in client else "red" for client in df["Client"]]


for i, grad in enumerate(grads):
    ax.scatter(pc1[i], pc2[i], pc3[i], color=colors[i])

ax.set_xlabel(rf"PC1 ({explained[0]:.2f}\%)")
ax.set_ylabel(rf"PC2 ({explained[1]:.2f}\%)")
ax.set_zlabel(rf"PC3 ({explained[2]:.2f}\%)")
ax.set_title("Cosine similarity", pad=-35)
# Out:
# Text(0.5, 0.0, 'Cosine similarity')

# %% [markdown]
# ### Testing Extraction Weigthing Parameters
#
# The goal is to identify if we can use the similarity matrix to deduce weights to use in the aggregation.

# %%
from pathlib import Path

import numpy as np
import numpy.linalg as LA
import pandas as pd
from eiffel.analysis.metrics import search_results
from sklearn.metrics.pairwise import cosine_similarity

paths = search_results(
    "similarity/results/",
    scenario="continuous-100",
    datasets=".*cicids",
    distribution="5-5",
    partitioner="kmeans_full",
    target="dos",
    seed=1138,
)

path = paths[0]

dfs: list[pd.DataFrame] = [pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")]
df = pd.concat(dfs, axis=0, ignore_index=True)
df["Client"] = df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))

df = df[df["Round"] == 10]
grads = np.array(df["Gradients"].to_list())

# centered and normalized gradients
grads = (grads - grads.mean(axis=1)[:, None]) / grads.std(axis=1)[:, None]

M = 1 - cosine_similarity(grads)  # cosine distance matrix
# add row with sum
M_ = np.vstack([M, M.sum(axis=0)])
# add column with sum
M_ = np.hstack([M_, M_.sum(axis=1)[:, None]])

vals, vecs = LA.eig(M)

M_prime = LA.inv(vecs) @ M @ vecs

pd.DataFrame(M_)
# Out:
#               0             1             2             3             4   \
# 0   3.108624e-15  1.089372e+00  1.076790e+00  1.027076e+00  1.156397e+00
# 1   1.089372e+00  4.440892e-16  1.046619e+00  1.036261e+00  3.536680e-01
# 2   1.076790e+00  1.046619e+00  2.997602e-15  1.100298e+00  1.007501e+00
# 3   1.027076e+00  1.036261e+00  1.100298e+00 -2.220446e-16  9.789969e-01
# 4   1.156397e+00  3.536680e-01  1.007501e+00  9.789969e-01 -1.776357e-15
# 5   1.019841e+00  6.615628e-01  1.132724e+00  8.157561e-01  6.270813e-01
# 6   9.584896e-01  8.970713e-01  6.833573e-01  8.465581e-01  8.593138e-01
# 7   8.363478e-01  1.244684e+00  9.026100e-01  1.046828e+00  1.235714e+00
# 8   1.017910e+00  4.637594e-01  8.974233e-01  1.090463e+00  2.808451e-01
# 9   9.863879e-01  6.945790e-01  1.044277e+00  9.103132e-01  6.133837e-01
# 10  9.168611e+00  7.487577e+00  8.891599e+00  8.852551e+00  7.112901e+00
#
#               5             6             7             8             9   \
# 0   1.019841e+00  9.584896e-01  8.363478e-01  1.017910e+00  9.863879e-01
# 1   6.615628e-01  8.970713e-01  1.244684e+00  4.637594e-01  6.945790e-01
# 2   1.132724e+00  6.833573e-01  9.026100e-01  8.974233e-01  1.044277e+00
# 3   8.157561e-01  8.465581e-01  1.046828e+00  1.090463e+00  9.103132e-01
# 4   6.270813e-01  8.593138e-01  1.235714e+00  2.808451e-01  6.133837e-01
# 5  -3.108624e-15  9.807839e-01  1.125678e+00  8.115055e-01  7.665900e-01
# 6   9.807839e-01 -2.664535e-15  1.202566e+00  8.328194e-01  9.190423e-01
# 7   1.125678e+00  1.202566e+00  6.661338e-16  1.228533e+00  1.164168e+00
# 8   8.115055e-01  8.328194e-01  1.228533e+00 -8.881784e-16  7.073534e-01
# 9   7.665900e-01  9.190423e-01  1.164168e+00  7.073534e-01  7.549517e-15
# 10  7.941523e+00  8.180001e+00  9.987129e+00  7.330612e+00  7.806094e+00
#
#            10
# 0    9.168611
# 1    7.487577
# 2    8.891599
# 3    8.852551
# 4    7.112901
# 5    7.941523
# 6    8.180001
# 7    9.987129
# 8    7.330612
# 9    7.806094
# 10  82.758599

# %%
vals  # eigenvalues
# Out:
# array([ 8.34865174, -2.27778128, -0.2221036 , -1.35318374, -1.19225868,
#        -0.94101925, -0.43668126, -0.50049982, -0.7559572 , -0.66916691])

# %%
np.argmax(np.sum(M, axis=1))
# Out:
# 7
