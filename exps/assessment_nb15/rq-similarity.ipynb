# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from matplotlib import backend_bases
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pgf import FigureCanvasPgf

# Make the interactive backend as PDF
backend_bases.register_backend("pdf", FigureCanvasPgf)

plt.style.use("acmcompat.mplstyle")

pd.options.mode.copy_on_write = True


def figsize(x, y, two_column=False):
    """Make a figure size with respect to a given width.

    Example:
    --------
    >>> mk_figsize(1, 1)
    (3.3374, 3.3374)
    >>> mk_figsize(1, 2)
    (3.3374, 6.6748)
    >>> mk_figsize(1, 1/3, two_column=True)
    (7.00697, 2.2258)
    """
    columnwidth = 3.3374
    textwidth = 7.00697

    w = textwidth if two_column else columnwidth
    return w * x, w * y


SAVEDIR = "/Users/leo/Workspace/imta/assessment-paper/src/figures/"

# %% [markdown]
# ## Executive Summary
#
# - **RQ0**: Is the experiment sound?
# - **RQ1**: Is the behavior of poisoning attacks predictable?
# - **RQ2**: Are there hyperparameter combinations that are beneficial or detrimental in poisoning situation?
# - **RQ3**: At what point do poisoning attacks start having an impact? (proportion of poisoned data/clients)
# - **RQ4**: Can FL recover from poisoning attacks after model aggregation? How long does it take?
# - **RQ5**: Are backdoor attacks realistic in IDS context?
# - **RQ6**: Is model similarity enough to detect poisoning attacks?

# %% [markdown]
# ## RQ6: Is model similarity enough to detect poisoning attacks?
#
#
# ### Test methodology
#
# ```yaml
# partitioner: glob(iid_*)
# +datasets: nfv2/sampled/cicids
# batch_size: 512
# +epochs: 100/10x10
# +distribution: 10-0,9-1,5-5
# +target: dos,ddos,bot,bruteforce,infiltration,untargeted
# +scenario: continuous-100
# seed: 1138,421,1313,5555,6567,327,2187,1977,501,3263827
# ```
#
# - goal is to evaluate the impact of dataset partitioning on the similarity of models, and therefore the ability to detect poisoning attacks in such a context
# - hyperparameters are fixed as the "best" ones from RQ2
# - $\alpha=100$
# - 3 benign-attackers distributions
#   - 0% attacker to see the impact of the partitioning performance
#   - 10% attackers (ie, one client) to see if his model is identifiable
#   - 50% attackers to see if similar attacks are detectable
# - all attacks to see if there are differences + untargeted

# %%
from eiffel.analysis.metrics import choices, display_choices

display_choices(choices("similarity/results/"))
# Out:
# similarity/results/: Not all theoritical combinations are covered: 2400 possibles, 1680 found.
# <style>table td, table th, table tr {text-align:left !important;}</style><table><tr><th>Key</th><th>Values</th></tr><tr><td>datasets</td><td>nfv2_sampled_nb15</td></tr><tr><td>distribution</td><td>5-5, 9-1, 10-0</td></tr><tr><td>epochs</td><td>100_10x10</td></tr><tr><td>scenario</td><td>continuous-100</td></tr><tr><td>target</td><td>generic, analysis, worms, backdoor, exploits, untargeted, shellcode, dos, reconnaissance, fuzzers</td></tr><tr><td>batch_size</td><td>512</td></tr><tr><td>partitioner</td><td>iid_drop_1, kmeans_full, kmeans_drop_2, kmeans_drop_1, iid_full, iid_drop_2, kmeans_keep_1, iid_keep_1</td></tr><tr><td>seed</td><td>501, 2187, 327, 1138, 3263827, 1977, 421, 1313, 6567, 5555</td></tr></table>

# %% [markdown]
# ### Partitioning effect on data distribution
#
# - make a dataframe with the the sample numbers in each partitioning scheme
#   - columns are the partitioning schemes
#   - rows are tuples "{partition}-{label}"

# %%
import json
import re
from pathlib import Path

import pandas as pd
from eiffel.analysis.metrics import search_results

SEED = 1138

paths = search_results(
    "similarity/results/",
    scenario="continuous-100",
    target="untargeted",
    datasets=".*nb15",
    distribution="10-0",
    seed=SEED,
)

part_re = r"partitioner=(\w+),"

stats_df = pd.DataFrame()

for path in paths:
    res = re.search(part_re, path)
    assert res is not None
    partitioner = res.group(1)

    idx = []
    samples = []

    stats = next(iter(json.loads((Path(path) / "stats.json").read_text()).values()))
    for k, v in stats.items():
        part = "_".join(k.split("_")[1:])
        train_stats: dict = v.get("train")
        assert train_stats is not None

        for label in [
            "Benign",
            "Exploits",
            "Reconnaissance",
            "DoS",
            "Generic",
            "Shellcode",
            "Fuzzers",
            "Worms",
            "Backdoor",
            "Analysis",
        ]:
            idx.append(f"{part}_{label}")
            n = train_stats.get(label)
            if n is None:
                n = 0
            samples.append(n)

        s = pd.Series(samples, index=idx, name=partitioner).astype(int)

    stats_df = pd.concat([stats_df, s], axis=1)

stats_df
# Out:
#                          iid_drop_1  iid_drop_2  iid_full  iid_keep_1  \
# benign_0_Benign               76807       76807     76807       76807
# benign_0_Exploits              1056        1056      1056           0
# benign_0_Reconnaissance         428         428       428           0
# benign_0_DoS                    196           0       196           0
# benign_0_Generic                559         559       559           0
# ...                             ...         ...       ...         ...
# benign_9_Shellcode               49          49        49           0
# benign_9_Fuzzers                749         749       749           0
# benign_9_Worms                    0           0         6           6
# benign_9_Backdoor                70          70        70           0
# benign_9_Analysis                80          80        80           0
#
#                          kmeans_drop_1  kmeans_drop_2  kmeans_full  \
# benign_0_Benign                  58251          58251        58251
# benign_0_Exploits                 1056           1056         1056
# benign_0_Reconnaissance            428            428          428
# benign_0_DoS                       196              0          196
# benign_0_Generic                   559            559          559
# ...                                ...            ...          ...
# benign_9_Shellcode                  49             49           49
# benign_9_Fuzzers                   749            749          749
# benign_9_Worms                       0              0            6
# benign_9_Backdoor                   70             70           70
# benign_9_Analysis                   80             80           80
#
#                          kmeans_keep_1
# benign_0_Benign                  58251
# benign_0_Exploits                    0
# benign_0_Reconnaissance              0
# benign_0_DoS                         0
# benign_0_Generic                     0
# ...                                ...
# benign_9_Shellcode                   0
# benign_9_Fuzzers                     0
# benign_9_Worms                       6
# benign_9_Backdoor                    0
# benign_9_Analysis                    0
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Impact on the benign scenario

# %%
from functools import partial

from eiffel.analysis.metrics import load_df, search_results

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    target="untargeted",
    datasets=".*nb15",
    distribution="10-0",
)

fig, ax = plt.subplots(
    1, 1, figsize=figsize(1, 0.8), constrained_layout=True, sharex=True, sharey=True
)

for i, partitioning in enumerate([
    "iid_full",
    "iid_drop_1",
    "iid_drop_2",
    "iid_keep_1",
    "kmeans_full",
    "kmeans_drop_1",
    "kmeans_drop_2",
    "kmeans_keep_1",
]):
    data = load_df(searchfn(partitioner=partitioning), dotpath="global.f1", attr="fit")

    ax.plot(data.mean(axis=0), label=partitioning)


ax.grid(axis="y", linestyle="--", alpha=0.5)
ax.set_ylabel("Accuracy", loc="top")

lgd = fig.legend(ncol=4, loc="upper center", bbox_to_anchor=(0.5, 1.15))

fig.savefig(
    SAVEDIR + "hyperparams-accdiff.pdf",
    bbox_extra_artists=(lgd,),
    bbox_inches="tight",
)

# %%
from functools import partial

import numpy as np
from eiffel.analysis.metrics import search_results
from sklearn.decomposition import PCA

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    target="untargeted",
    datasets=".*nb15",
    distribution="10-0",
)

grads_df = pd.DataFrame()
seed_re = r"seed=(\d+)(?:,.*)?"

for partitioner in [
    "iid_full",
    "iid_drop_1",
    "iid_drop_2",
    "iid_keep_1",
    "kmeans_full",
    "kmeans_drop_1",
    "kmeans_drop_2",
    "kmeans_keep_1",
]:
    for path in searchfn(partitioner=partitioner):
        res = re.search(seed_re, path)
        assert res is not None
        seed = res.group(1)
        part_grads_dfs: list[pd.DataFrame] = [
            pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")
        ]
        part_grads_df = pd.concat(part_grads_dfs, axis=0)
        part_grads_df["Partitioner"] = partitioner
        part_grads_df["Seed"] = seed
        grads_df = pd.concat([grads_df, part_grads_df], axis=0, ignore_index=True)

grads_array = np.array(grads_df["Gradients"].tolist())
grads_array = (grads_array - grads_array.mean(axis=0)) / grads_array.std(axis=0)
pca = PCA(n_components=2)
grads_pca = pca.fit_transform(grads_array)

grads_df["PCA1"] = grads_pca[:, 0]
grads_df["PCA2"] = grads_pca[:, 1]

grads_df["Client"] = grads_df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))

# %%
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import NullLocator

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

df = grads_df  # [grads_df["Seed"] == "1138"]

levels, categories = pd.factorize(df["Client"])
df["Color"] = [plt.cm.tab10(i) for i in levels]
handles = [Patch(color=plt.cm.tab10(i), label=c) for i, c in enumerate(categories)]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[df["Partitioner"] == partitioner]

    ax.scatter(data["PCA1"], data["PCA2"], s=1, c=data["Color"])


lgd = fig.legend(handles=handles, ncol=5, loc="upper center", bbox_to_anchor=(0.5, 1.1))
fig.suptitle("Gradients in 2D, colored by client")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by client')

# %%
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import NullLocator

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

df = grads_df[grads_df["Round"] == 10]

levels, categories = pd.factorize(df["Client"])
df["Color"] = [plt.cm.tab10(i) for i in levels]
handles = [Patch(color=plt.cm.tab10(i), label=c) for i, c in enumerate(categories)]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[df["Partitioner"] == partitioner]

    ax.scatter(data["PCA1"], data["PCA2"], s=1, c=data["Color"])


lgd = fig.legend(handles=handles, ncol=5, loc="upper center", bbox_to_anchor=(0.5, 1.1))
fig.suptitle("Gradients in 2D, colored by client")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by client')

# %%
from matplotlib import pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import NullLocator

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

df = grads_df[grads_df["Seed"] == "1138"]

levels, categories = pd.factorize(df["Round"])
df["Color"] = [plt.cm.tab10(i) for i in levels]
handles = [Patch(color=plt.cm.tab10(i), label=c) for i, c in enumerate(categories)]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[df["Partitioner"] == partitioner]

    ax.scatter(data["PCA1"], data["PCA2"], s=1, c=data["Color"])


lgd = fig.legend(handles=handles, ncol=5, loc="upper center", bbox_to_anchor=(0.5, 1.1))
fig.suptitle("Gradients in 2D, colored by round")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by round')

# %% [markdown]
# ### Identifiability of one lone attacker

# %%
import itertools
from functools import partial
from pathlib import Path

import pandas as pd
from eiffel.analysis.metrics import search_results

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    datasets=".*nb15",
    distribution="9-1",
)

grads_df = pd.DataFrame()

for target, partitioner, seed in itertools.product(
    [
        "untargeted",
        "exploits",
        "reconnaissance",
        "dos",
        "generic",
        "shellcode",
        "fuzzers",
        "worms",
        "backdoor",
        "analysis",
        # "injection" has been removed due to its low representation
    ],
    [
        "iid_full",
        "iid_drop_1",
        "iid_drop_2",
        "iid_keep_1",
        "kmeans_full",
        "kmeans_drop_1",
        "kmeans_drop_2",
        "kmeans_keep_1",
    ],
    [1138, 421, 1313, 5555, 6567, 327, 2187, 1977, 501, 3263827],
):
    print(f"Loading: {target}, {partitioner}, {seed}")

    paths = searchfn(partitioner=partitioner, target=target, seed=seed)
    assert len(paths) == 1
    path = paths[0]
    part_grads_dfs: list[pd.DataFrame] = [
        pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")
    ]
    assert part_grads_dfs[0].shape[0] == 10  # ten client per partition
    assert len(part_grads_dfs) == 10  # ten clients

    part_grads_df = pd.concat(part_grads_dfs, axis=0, ignore_index=True)
    part_grads_df["Partitioner"] = partitioner
    part_grads_df["Target"] = target
    part_grads_df["Seed"] = seed

    grads_df = pd.concat([grads_df, part_grads_df], axis=0, ignore_index=True)

print("Loaded all gradients")

for seed in [1138, 421, 1313, 5555, 6567, 327, 2187, 1977, 501, 3263827]:
    mask = grads_df["Seed"] == seed
    grads_array = np.array(grads_df.loc[mask, "Gradients"].tolist())
    grads_pca = PCA(n_components=2).fit_transform(grads_array)

    grads_df.loc[mask, "PCA1"] = grads_pca[:, 0]
    grads_df.loc[mask, "PCA2"] = grads_pca[:, 1]


# grads_array = np.array(grads_df["Gradients"].tolist())
# # grads_array = StandardScaler().fit_transform(grads_array) -> useless as the gradients
# #                                                             are already normalized
# #                                                             (all parameters are in the
# #                                                             same range)

# grads_pca = PCA(n_components=2).fit_transform(grads_array)

# grads_df["PCA1"] = grads_pca[:, 0]
# grads_df["PCA2"] = grads_pca[:, 1]

grads_df["Client"] = grads_df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))
# Out:
# Loading: untargeted, iid_full, 1138
# Loading: untargeted, iid_full, 421
# Loading: untargeted, iid_full, 1313
# Loading: untargeted, iid_full, 5555
# Loading: untargeted, iid_full, 6567
# Loading: untargeted, iid_full, 327
# Loading: untargeted, iid_full, 2187
# Loading: untargeted, iid_full, 1977
# Loading: untargeted, iid_full, 501
# Loading: untargeted, iid_full, 3263827
# Loading: untargeted, iid_drop_1, 1138
# Loading: untargeted, iid_drop_1, 421
# Loading: untargeted, iid_drop_1, 1313
# Loading: untargeted, iid_drop_1, 5555
# Loading: untargeted, iid_drop_1, 6567
# Loading: untargeted, iid_drop_1, 327
# Loading: untargeted, iid_drop_1, 2187
# Loading: untargeted, iid_drop_1, 1977
# Loading: untargeted, iid_drop_1, 501
# Loading: untargeted, iid_drop_1, 3263827
# Loading: untargeted, iid_drop_2, 1138
# Loading: untargeted, iid_drop_2, 421
# Loading: untargeted, iid_drop_2, 1313
# Loading: untargeted, iid_drop_2, 5555
# Loading: untargeted, iid_drop_2, 6567
# Loading: untargeted, iid_drop_2, 327
# Loading: untargeted, iid_drop_2, 2187
# Loading: untargeted, iid_drop_2, 1977
# Loading: untargeted, iid_drop_2, 501
# Loading: untargeted, iid_drop_2, 3263827
# Loading: untargeted, iid_keep_1, 1138
# Loading: untargeted, iid_keep_1, 421
# Loading: untargeted, iid_keep_1, 1313
# Loading: untargeted, iid_keep_1, 5555
# Loading: untargeted, iid_keep_1, 6567
# Loading: untargeted, iid_keep_1, 327
# Loading: untargeted, iid_keep_1, 2187
# Loading: untargeted, iid_keep_1, 1977
# Loading: untargeted, iid_keep_1, 501
# Loading: untargeted, iid_keep_1, 3263827
# Loading: untargeted, kmeans_full, 1138
# Loading: untargeted, kmeans_full, 421
# Loading: untargeted, kmeans_full, 1313
# Loading: untargeted, kmeans_full, 5555
# Loading: untargeted, kmeans_full, 6567
# Loading: untargeted, kmeans_full, 327
# Loading: untargeted, kmeans_full, 2187
# Loading: untargeted, kmeans_full, 1977
# Loading: untargeted, kmeans_full, 501
# Loading: untargeted, kmeans_full, 3263827
# Loading: untargeted, kmeans_drop_1, 1138
# Loading: untargeted, kmeans_drop_1, 421
# Loading: untargeted, kmeans_drop_1, 1313
# Loading: untargeted, kmeans_drop_1, 5555
# Loading: untargeted, kmeans_drop_1, 6567
# Loading: untargeted, kmeans_drop_1, 327
# Loading: untargeted, kmeans_drop_1, 2187
# Loading: untargeted, kmeans_drop_1, 1977
# Loading: untargeted, kmeans_drop_1, 501
# Loading: untargeted, kmeans_drop_1, 3263827
# Loading: untargeted, kmeans_drop_2, 1138
# Loading: untargeted, kmeans_drop_2, 421
# Loading: untargeted, kmeans_drop_2, 1313
# Loading: untargeted, kmeans_drop_2, 5555
# Loading: untargeted, kmeans_drop_2, 6567
# Loading: untargeted, kmeans_drop_2, 327
# Loading: untargeted, kmeans_drop_2, 2187
# Loading: untargeted, kmeans_drop_2, 1977
# Loading: untargeted, kmeans_drop_2, 501
# Loading: untargeted, kmeans_drop_2, 3263827
# Loading: untargeted, kmeans_keep_1, 1138
# Loading: untargeted, kmeans_keep_1, 421
# Loading: untargeted, kmeans_keep_1, 1313
# Loading: untargeted, kmeans_keep_1, 5555
# Loading: untargeted, kmeans_keep_1, 6567
# Loading: untargeted, kmeans_keep_1, 327
# Loading: untargeted, kmeans_keep_1, 2187
# Loading: untargeted, kmeans_keep_1, 1977
# Loading: untargeted, kmeans_keep_1, 501
# Loading: untargeted, kmeans_keep_1, 3263827
# Loading: exploits, iid_full, 1138
# Loading: exploits, iid_full, 421
# Loading: exploits, iid_full, 1313
# Loading: exploits, iid_full, 5555
# Loading: exploits, iid_full, 6567
# Loading: exploits, iid_full, 327
# Loading: exploits, iid_full, 2187
# Loading: exploits, iid_full, 1977
# Loading: exploits, iid_full, 501
# Loading: exploits, iid_full, 3263827
# Loading: exploits, iid_drop_1, 1138
# Loading: exploits, iid_drop_1, 421
# Loading: exploits, iid_drop_1, 1313
# Loading: exploits, iid_drop_1, 5555
# Loading: exploits, iid_drop_1, 6567
# Loading: exploits, iid_drop_1, 327
# Loading: exploits, iid_drop_1, 2187
# Loading: exploits, iid_drop_1, 1977
# Loading: exploits, iid_drop_1, 501
# Loading: exploits, iid_drop_1, 3263827
# Loading: exploits, iid_drop_2, 1138
# Loading: exploits, iid_drop_2, 421
# Loading: exploits, iid_drop_2, 1313
# Loading: exploits, iid_drop_2, 5555
# Loading: exploits, iid_drop_2, 6567
# Loading: exploits, iid_drop_2, 327
# Loading: exploits, iid_drop_2, 2187
# Loading: exploits, iid_drop_2, 1977
# Loading: exploits, iid_drop_2, 501
# Loading: exploits, iid_drop_2, 3263827
# Loading: exploits, iid_keep_1, 1138
# Loading: exploits, iid_keep_1, 421
# Loading: exploits, iid_keep_1, 1313
# Loading: exploits, iid_keep_1, 5555
# Loading: exploits, iid_keep_1, 6567
# Loading: exploits, iid_keep_1, 327
# Loading: exploits, iid_keep_1, 2187
# Loading: exploits, iid_keep_1, 1977
# Loading: exploits, iid_keep_1, 501
# Loading: exploits, iid_keep_1, 3263827
# Loading: exploits, kmeans_full, 1138
# Loading: exploits, kmeans_full, 421
# Loading: exploits, kmeans_full, 1313
# Loading: exploits, kmeans_full, 5555
# Loading: exploits, kmeans_full, 6567
# Loading: exploits, kmeans_full, 327
# Loading: exploits, kmeans_full, 2187
# Loading: exploits, kmeans_full, 1977
# Loading: exploits, kmeans_full, 501
# Loading: exploits, kmeans_full, 3263827
# Loading: exploits, kmeans_drop_1, 1138
# Loading: exploits, kmeans_drop_1, 421
# Loading: exploits, kmeans_drop_1, 1313
# Loading: exploits, kmeans_drop_1, 5555
# Loading: exploits, kmeans_drop_1, 6567
# Loading: exploits, kmeans_drop_1, 327
# Loading: exploits, kmeans_drop_1, 2187
# Loading: exploits, kmeans_drop_1, 1977
# Loading: exploits, kmeans_drop_1, 501
# Loading: exploits, kmeans_drop_1, 3263827
# Loading: exploits, kmeans_drop_2, 1138
# Loading: exploits, kmeans_drop_2, 421
# Loading: exploits, kmeans_drop_2, 1313
# Loading: exploits, kmeans_drop_2, 5555
# Loading: exploits, kmeans_drop_2, 6567
# Loading: exploits, kmeans_drop_2, 327
# Loading: exploits, kmeans_drop_2, 2187
# Loading: exploits, kmeans_drop_2, 1977
# Loading: exploits, kmeans_drop_2, 501
# Loading: exploits, kmeans_drop_2, 3263827
# Loading: exploits, kmeans_keep_1, 1138
# Loading: exploits, kmeans_keep_1, 421
# Loading: exploits, kmeans_keep_1, 1313
# Loading: exploits, kmeans_keep_1, 5555
# Loading: exploits, kmeans_keep_1, 6567
# Loading: exploits, kmeans_keep_1, 327
# Loading: exploits, kmeans_keep_1, 2187
# Loading: exploits, kmeans_keep_1, 1977
# Loading: exploits, kmeans_keep_1, 501
# Loading: exploits, kmeans_keep_1, 3263827
# Loading: reconnaissance, iid_full, 1138
# Loading: reconnaissance, iid_full, 421
# Loading: reconnaissance, iid_full, 1313
# Loading: reconnaissance, iid_full, 5555
# Loading: reconnaissance, iid_full, 6567
# Loading: reconnaissance, iid_full, 327
# Loading: reconnaissance, iid_full, 2187
# Loading: reconnaissance, iid_full, 1977
# Loading: reconnaissance, iid_full, 501
# Loading: reconnaissance, iid_full, 3263827
# Loading: reconnaissance, iid_drop_1, 1138
# Loading: reconnaissance, iid_drop_1, 421
# Loading: reconnaissance, iid_drop_1, 1313
# Loading: reconnaissance, iid_drop_1, 5555
# Loading: reconnaissance, iid_drop_1, 6567
# Loading: reconnaissance, iid_drop_1, 327
# Loading: reconnaissance, iid_drop_1, 2187
# Loading: reconnaissance, iid_drop_1, 1977
# Loading: reconnaissance, iid_drop_1, 501
# Loading: reconnaissance, iid_drop_1, 3263827
# Loading: reconnaissance, iid_drop_2, 1138
# Loading: reconnaissance, iid_drop_2, 421
# Loading: reconnaissance, iid_drop_2, 1313
# Loading: reconnaissance, iid_drop_2, 5555
# Loading: reconnaissance, iid_drop_2, 6567
# Loading: reconnaissance, iid_drop_2, 327
# Loading: reconnaissance, iid_drop_2, 2187
# Loading: reconnaissance, iid_drop_2, 1977
# Loading: reconnaissance, iid_drop_2, 501
# Loading: reconnaissance, iid_drop_2, 3263827
# Loading: reconnaissance, iid_keep_1, 1138
# Loading: reconnaissance, iid_keep_1, 421
# Loading: reconnaissance, iid_keep_1, 1313
# Loading: reconnaissance, iid_keep_1, 5555
# Loading: reconnaissance, iid_keep_1, 6567
# Loading: reconnaissance, iid_keep_1, 327
# Loading: reconnaissance, iid_keep_1, 2187
# Loading: reconnaissance, iid_keep_1, 1977
# Loading: reconnaissance, iid_keep_1, 501
# Loading: reconnaissance, iid_keep_1, 3263827
# Loading: reconnaissance, kmeans_full, 1138
# Loading: reconnaissance, kmeans_full, 421
# Loading: reconnaissance, kmeans_full, 1313
# Loading: reconnaissance, kmeans_full, 5555
# Loading: reconnaissance, kmeans_full, 6567
# Loading: reconnaissance, kmeans_full, 327
# Loading: reconnaissance, kmeans_full, 2187
# Loading: reconnaissance, kmeans_full, 1977
# Loading: reconnaissance, kmeans_full, 501
# Loading: reconnaissance, kmeans_full, 3263827
# Loading: reconnaissance, kmeans_drop_1, 1138
# Loading: reconnaissance, kmeans_drop_1, 421
# Loading: reconnaissance, kmeans_drop_1, 1313
# Loading: reconnaissance, kmeans_drop_1, 5555
# Loading: reconnaissance, kmeans_drop_1, 6567
# Loading: reconnaissance, kmeans_drop_1, 327
# Loading: reconnaissance, kmeans_drop_1, 2187
# Loading: reconnaissance, kmeans_drop_1, 1977
# Loading: reconnaissance, kmeans_drop_1, 501
# Loading: reconnaissance, kmeans_drop_1, 3263827
# Loading: reconnaissance, kmeans_drop_2, 1138
# Loading: reconnaissance, kmeans_drop_2, 421
# Loading: reconnaissance, kmeans_drop_2, 1313
# Loading: reconnaissance, kmeans_drop_2, 5555
# Loading: reconnaissance, kmeans_drop_2, 6567
# Loading: reconnaissance, kmeans_drop_2, 327
# Loading: reconnaissance, kmeans_drop_2, 2187
# Loading: reconnaissance, kmeans_drop_2, 1977
# Loading: reconnaissance, kmeans_drop_2, 501
# Loading: reconnaissance, kmeans_drop_2, 3263827
# Loading: reconnaissance, kmeans_keep_1, 1138
# Loading: reconnaissance, kmeans_keep_1, 421
# Loading: reconnaissance, kmeans_keep_1, 1313
# Loading: reconnaissance, kmeans_keep_1, 5555
# Loading: reconnaissance, kmeans_keep_1, 6567
# Loading: reconnaissance, kmeans_keep_1, 327
# Loading: reconnaissance, kmeans_keep_1, 2187
# Loading: reconnaissance, kmeans_keep_1, 1977
# Loading: reconnaissance, kmeans_keep_1, 501
# Loading: reconnaissance, kmeans_keep_1, 3263827
# Loading: dos, iid_full, 1138
# Loading: dos, iid_full, 421
# Loading: dos, iid_full, 1313
# Loading: dos, iid_full, 5555
# Loading: dos, iid_full, 6567
# Loading: dos, iid_full, 327
# Loading: dos, iid_full, 2187
# Loading: dos, iid_full, 1977
# Loading: dos, iid_full, 501
# Loading: dos, iid_full, 3263827
# Loading: dos, iid_drop_1, 1138
# Loading: dos, iid_drop_1, 421
# Loading: dos, iid_drop_1, 1313
# Loading: dos, iid_drop_1, 5555
# Loading: dos, iid_drop_1, 6567
# Loading: dos, iid_drop_1, 327
# Loading: dos, iid_drop_1, 2187
# Loading: dos, iid_drop_1, 1977
# Loading: dos, iid_drop_1, 501
# Loading: dos, iid_drop_1, 3263827
# Loading: dos, iid_drop_2, 1138
# Loading: dos, iid_drop_2, 421
# Loading: dos, iid_drop_2, 1313
# Loading: dos, iid_drop_2, 5555
# Loading: dos, iid_drop_2, 6567
# Loading: dos, iid_drop_2, 327
# Loading: dos, iid_drop_2, 2187
# Loading: dos, iid_drop_2, 1977
# Loading: dos, iid_drop_2, 501
# Loading: dos, iid_drop_2, 3263827
# Loading: dos, iid_keep_1, 1138
# Loading: dos, iid_keep_1, 421
# Loading: dos, iid_keep_1, 1313
# Loading: dos, iid_keep_1, 5555
# Loading: dos, iid_keep_1, 6567
# Loading: dos, iid_keep_1, 327
# Loading: dos, iid_keep_1, 2187
# Loading: dos, iid_keep_1, 1977
# Loading: dos, iid_keep_1, 501
# Loading: dos, iid_keep_1, 3263827
# Loading: dos, kmeans_full, 1138
# Loading: dos, kmeans_full, 421
# Loading: dos, kmeans_full, 1313
# Loading: dos, kmeans_full, 5555
# Loading: dos, kmeans_full, 6567
# Loading: dos, kmeans_full, 327
# Loading: dos, kmeans_full, 2187
# Loading: dos, kmeans_full, 1977
# Loading: dos, kmeans_full, 501
# Loading: dos, kmeans_full, 3263827
# Loading: dos, kmeans_drop_1, 1138
# Loading: dos, kmeans_drop_1, 421
# Loading: dos, kmeans_drop_1, 1313
# Loading: dos, kmeans_drop_1, 5555
# Loading: dos, kmeans_drop_1, 6567
# Loading: dos, kmeans_drop_1, 327
# Loading: dos, kmeans_drop_1, 2187
# Loading: dos, kmeans_drop_1, 1977
# Loading: dos, kmeans_drop_1, 501
# Loading: dos, kmeans_drop_1, 3263827
# Loading: dos, kmeans_drop_2, 1138
# Loading: dos, kmeans_drop_2, 421
# Loading: dos, kmeans_drop_2, 1313
# Loading: dos, kmeans_drop_2, 5555
# Loading: dos, kmeans_drop_2, 6567
# Loading: dos, kmeans_drop_2, 327
# Loading: dos, kmeans_drop_2, 2187
# Loading: dos, kmeans_drop_2, 1977
# Loading: dos, kmeans_drop_2, 501
# Loading: dos, kmeans_drop_2, 3263827
# Loading: dos, kmeans_keep_1, 1138
# Loading: dos, kmeans_keep_1, 421
# Loading: dos, kmeans_keep_1, 1313
# Loading: dos, kmeans_keep_1, 5555
# Loading: dos, kmeans_keep_1, 6567
# Loading: dos, kmeans_keep_1, 327
# Loading: dos, kmeans_keep_1, 2187
# Loading: dos, kmeans_keep_1, 1977
# Loading: dos, kmeans_keep_1, 501
# Loading: dos, kmeans_keep_1, 3263827
# Loading: generic, iid_full, 1138
# Loading: generic, iid_full, 421
# Loading: generic, iid_full, 1313
# Loading: generic, iid_full, 5555
# Loading: generic, iid_full, 6567
# Loading: generic, iid_full, 327
# Loading: generic, iid_full, 2187
# Loading: generic, iid_full, 1977
# Loading: generic, iid_full, 501
# Loading: generic, iid_full, 3263827
# Loading: generic, iid_drop_1, 1138
# Loading: generic, iid_drop_1, 421
# Loading: generic, iid_drop_1, 1313
# Loading: generic, iid_drop_1, 5555
# Loading: generic, iid_drop_1, 6567
# Loading: generic, iid_drop_1, 327
# Loading: generic, iid_drop_1, 2187
# Loading: generic, iid_drop_1, 1977
# Loading: generic, iid_drop_1, 501
# Loading: generic, iid_drop_1, 3263827
# Loading: generic, iid_drop_2, 1138
# Loading: generic, iid_drop_2, 421
# Loading: generic, iid_drop_2, 1313
# Loading: generic, iid_drop_2, 5555
# Loading: generic, iid_drop_2, 6567
# Loading: generic, iid_drop_2, 327
# Loading: generic, iid_drop_2, 2187
# Loading: generic, iid_drop_2, 1977
# Loading: generic, iid_drop_2, 501
# Loading: generic, iid_drop_2, 3263827
# Loading: generic, iid_keep_1, 1138
# Loading: generic, iid_keep_1, 421
# Loading: generic, iid_keep_1, 1313
# Loading: generic, iid_keep_1, 5555
# Loading: generic, iid_keep_1, 6567
# Loading: generic, iid_keep_1, 327
# Loading: generic, iid_keep_1, 2187
# Loading: generic, iid_keep_1, 1977
# Loading: generic, iid_keep_1, 501
# Loading: generic, iid_keep_1, 3263827
# Loading: generic, kmeans_full, 1138
# Loading: generic, kmeans_full, 421
# Loading: generic, kmeans_full, 1313
# Loading: generic, kmeans_full, 5555
# Loading: generic, kmeans_full, 6567
# Loading: generic, kmeans_full, 327
# Loading: generic, kmeans_full, 2187
# Loading: generic, kmeans_full, 1977
# Loading: generic, kmeans_full, 501
# Loading: generic, kmeans_full, 3263827
# Loading: generic, kmeans_drop_1, 1138
# Loading: generic, kmeans_drop_1, 421
# Loading: generic, kmeans_drop_1, 1313
# Loading: generic, kmeans_drop_1, 5555
# Loading: generic, kmeans_drop_1, 6567
# Loading: generic, kmeans_drop_1, 327
# Loading: generic, kmeans_drop_1, 2187
# Loading: generic, kmeans_drop_1, 1977
# Loading: generic, kmeans_drop_1, 501
# Loading: generic, kmeans_drop_1, 3263827
# Loading: generic, kmeans_drop_2, 1138
# Loading: generic, kmeans_drop_2, 421
# Loading: generic, kmeans_drop_2, 1313
# Loading: generic, kmeans_drop_2, 5555
# Loading: generic, kmeans_drop_2, 6567
# Loading: generic, kmeans_drop_2, 327
# Loading: generic, kmeans_drop_2, 2187
# Loading: generic, kmeans_drop_2, 1977
# Loading: generic, kmeans_drop_2, 501
# Loading: generic, kmeans_drop_2, 3263827
# Loading: generic, kmeans_keep_1, 1138
# Loading: generic, kmeans_keep_1, 421
# Loading: generic, kmeans_keep_1, 1313
# Loading: generic, kmeans_keep_1, 5555
# Loading: generic, kmeans_keep_1, 6567
# Loading: generic, kmeans_keep_1, 327
# Loading: generic, kmeans_keep_1, 2187
# Loading: generic, kmeans_keep_1, 1977
# Loading: generic, kmeans_keep_1, 501
# Loading: generic, kmeans_keep_1, 3263827
# Loading: shellcode, iid_full, 1138
# Loading: shellcode, iid_full, 421
# Loading: shellcode, iid_full, 1313
# Loading: shellcode, iid_full, 5555
# Loading: shellcode, iid_full, 6567
# Loading: shellcode, iid_full, 327
# Loading: shellcode, iid_full, 2187
# Loading: shellcode, iid_full, 1977
# Loading: shellcode, iid_full, 501
# Loading: shellcode, iid_full, 3263827
# Loading: shellcode, iid_drop_1, 1138
# Loading: shellcode, iid_drop_1, 421
# Loading: shellcode, iid_drop_1, 1313
# Loading: shellcode, iid_drop_1, 5555
# Loading: shellcode, iid_drop_1, 6567
# Loading: shellcode, iid_drop_1, 327
# Loading: shellcode, iid_drop_1, 2187
# Loading: shellcode, iid_drop_1, 1977
# Loading: shellcode, iid_drop_1, 501
# Loading: shellcode, iid_drop_1, 3263827
# Loading: shellcode, iid_drop_2, 1138
# Loading: shellcode, iid_drop_2, 421
# Loading: shellcode, iid_drop_2, 1313
# Loading: shellcode, iid_drop_2, 5555
# Loading: shellcode, iid_drop_2, 6567
# Loading: shellcode, iid_drop_2, 327
# Loading: shellcode, iid_drop_2, 2187
# Loading: shellcode, iid_drop_2, 1977
# Loading: shellcode, iid_drop_2, 501
# Loading: shellcode, iid_drop_2, 3263827
# Loading: shellcode, iid_keep_1, 1138
# Loading: shellcode, iid_keep_1, 421
# Loading: shellcode, iid_keep_1, 1313
# Loading: shellcode, iid_keep_1, 5555
# Loading: shellcode, iid_keep_1, 6567
# Loading: shellcode, iid_keep_1, 327
# Loading: shellcode, iid_keep_1, 2187
# Loading: shellcode, iid_keep_1, 1977
# Loading: shellcode, iid_keep_1, 501
# Loading: shellcode, iid_keep_1, 3263827
# Loading: shellcode, kmeans_full, 1138
# Loading: shellcode, kmeans_full, 421
# Loading: shellcode, kmeans_full, 1313
# Loading: shellcode, kmeans_full, 5555
# Loading: shellcode, kmeans_full, 6567
# Loading: shellcode, kmeans_full, 327
# Loading: shellcode, kmeans_full, 2187
# Loading: shellcode, kmeans_full, 1977
# Loading: shellcode, kmeans_full, 501
# Loading: shellcode, kmeans_full, 3263827
# Loading: shellcode, kmeans_drop_1, 1138
# Loading: shellcode, kmeans_drop_1, 421
# Loading: shellcode, kmeans_drop_1, 1313
# Loading: shellcode, kmeans_drop_1, 5555
# Loading: shellcode, kmeans_drop_1, 6567
# Loading: shellcode, kmeans_drop_1, 327
# Loading: shellcode, kmeans_drop_1, 2187
# Loading: shellcode, kmeans_drop_1, 1977
# Loading: shellcode, kmeans_drop_1, 501
# Loading: shellcode, kmeans_drop_1, 3263827
# Loading: shellcode, kmeans_drop_2, 1138
# Loading: shellcode, kmeans_drop_2, 421
# Loading: shellcode, kmeans_drop_2, 1313
# Loading: shellcode, kmeans_drop_2, 5555
# Loading: shellcode, kmeans_drop_2, 6567
# Loading: shellcode, kmeans_drop_2, 327
# Loading: shellcode, kmeans_drop_2, 2187
# Loading: shellcode, kmeans_drop_2, 1977
# Loading: shellcode, kmeans_drop_2, 501
# Loading: shellcode, kmeans_drop_2, 3263827
# Loading: shellcode, kmeans_keep_1, 1138
# Loading: shellcode, kmeans_keep_1, 421
# Loading: shellcode, kmeans_keep_1, 1313
# Loading: shellcode, kmeans_keep_1, 5555
# Loading: shellcode, kmeans_keep_1, 6567
# Loading: shellcode, kmeans_keep_1, 327
# Loading: shellcode, kmeans_keep_1, 2187
# Loading: shellcode, kmeans_keep_1, 1977
# Loading: shellcode, kmeans_keep_1, 501
# Loading: shellcode, kmeans_keep_1, 3263827
# Loading: fuzzers, iid_full, 1138
# Loading: fuzzers, iid_full, 421
# Loading: fuzzers, iid_full, 1313
# Loading: fuzzers, iid_full, 5555
# Loading: fuzzers, iid_full, 6567
# Loading: fuzzers, iid_full, 327
# Loading: fuzzers, iid_full, 2187
# Loading: fuzzers, iid_full, 1977
# Loading: fuzzers, iid_full, 501
# Loading: fuzzers, iid_full, 3263827
# Loading: fuzzers, iid_drop_1, 1138
# Loading: fuzzers, iid_drop_1, 421
# Loading: fuzzers, iid_drop_1, 1313
# Loading: fuzzers, iid_drop_1, 5555
# Loading: fuzzers, iid_drop_1, 6567
# Loading: fuzzers, iid_drop_1, 327
# Loading: fuzzers, iid_drop_1, 2187
# Loading: fuzzers, iid_drop_1, 1977
# Loading: fuzzers, iid_drop_1, 501
# Loading: fuzzers, iid_drop_1, 3263827
# Loading: fuzzers, iid_drop_2, 1138
# Loading: fuzzers, iid_drop_2, 421
# Loading: fuzzers, iid_drop_2, 1313
# Loading: fuzzers, iid_drop_2, 5555
# Loading: fuzzers, iid_drop_2, 6567
# Loading: fuzzers, iid_drop_2, 327
# Loading: fuzzers, iid_drop_2, 2187
# Loading: fuzzers, iid_drop_2, 1977
# Loading: fuzzers, iid_drop_2, 501
# Loading: fuzzers, iid_drop_2, 3263827
# Loading: fuzzers, iid_keep_1, 1138
# Loading: fuzzers, iid_keep_1, 421
# Loading: fuzzers, iid_keep_1, 1313
# Loading: fuzzers, iid_keep_1, 5555
# Loading: fuzzers, iid_keep_1, 6567
# Loading: fuzzers, iid_keep_1, 327
# Loading: fuzzers, iid_keep_1, 2187
# Loading: fuzzers, iid_keep_1, 1977
# Loading: fuzzers, iid_keep_1, 501
# Loading: fuzzers, iid_keep_1, 3263827
# Loading: fuzzers, kmeans_full, 1138
# Loading: fuzzers, kmeans_full, 421
# Loading: fuzzers, kmeans_full, 1313
# Loading: fuzzers, kmeans_full, 5555
# Loading: fuzzers, kmeans_full, 6567
# Loading: fuzzers, kmeans_full, 327
# Loading: fuzzers, kmeans_full, 2187
# Loading: fuzzers, kmeans_full, 1977
# Loading: fuzzers, kmeans_full, 501
# Loading: fuzzers, kmeans_full, 3263827
# Loading: fuzzers, kmeans_drop_1, 1138
# Loading: fuzzers, kmeans_drop_1, 421
# Loading: fuzzers, kmeans_drop_1, 1313
# Loading: fuzzers, kmeans_drop_1, 5555
# Loading: fuzzers, kmeans_drop_1, 6567
# Loading: fuzzers, kmeans_drop_1, 327
# Loading: fuzzers, kmeans_drop_1, 2187
# Loading: fuzzers, kmeans_drop_1, 1977
# Loading: fuzzers, kmeans_drop_1, 501
# Loading: fuzzers, kmeans_drop_1, 3263827
# Loading: fuzzers, kmeans_drop_2, 1138
# Loading: fuzzers, kmeans_drop_2, 421
# Loading: fuzzers, kmeans_drop_2, 1313
# Loading: fuzzers, kmeans_drop_2, 5555
# Loading: fuzzers, kmeans_drop_2, 6567
# Loading: fuzzers, kmeans_drop_2, 327
# Loading: fuzzers, kmeans_drop_2, 2187
# Loading: fuzzers, kmeans_drop_2, 1977
# Loading: fuzzers, kmeans_drop_2, 501
# Loading: fuzzers, kmeans_drop_2, 3263827
# Loading: fuzzers, kmeans_keep_1, 1138
# Loading: fuzzers, kmeans_keep_1, 421
# Loading: fuzzers, kmeans_keep_1, 1313
# Loading: fuzzers, kmeans_keep_1, 5555
# Loading: fuzzers, kmeans_keep_1, 6567
# Loading: fuzzers, kmeans_keep_1, 327
# Loading: fuzzers, kmeans_keep_1, 2187
# Loading: fuzzers, kmeans_keep_1, 1977
# Loading: fuzzers, kmeans_keep_1, 501
# Loading: fuzzers, kmeans_keep_1, 3263827
# Loading: worms, iid_full, 1138
# Loading: worms, iid_full, 421
# Loading: worms, iid_full, 1313
# Loading: worms, iid_full, 5555
# Loading: worms, iid_full, 6567
# Loading: worms, iid_full, 327
# Loading: worms, iid_full, 2187
# Loading: worms, iid_full, 1977
# Loading: worms, iid_full, 501
# Loading: worms, iid_full, 3263827
# Loading: worms, iid_drop_1, 1138
# Loading: worms, iid_drop_1, 421
# Loading: worms, iid_drop_1, 1313
# Loading: worms, iid_drop_1, 5555
# Loading: worms, iid_drop_1, 6567
# Loading: worms, iid_drop_1, 327
# Loading: worms, iid_drop_1, 2187
# Loading: worms, iid_drop_1, 1977
# Loading: worms, iid_drop_1, 501
# Loading: worms, iid_drop_1, 3263827
# Loading: worms, iid_drop_2, 1138
# Loading: worms, iid_drop_2, 421
# Loading: worms, iid_drop_2, 1313
# Loading: worms, iid_drop_2, 5555
# Loading: worms, iid_drop_2, 6567
# Loading: worms, iid_drop_2, 327
# Loading: worms, iid_drop_2, 2187
# Loading: worms, iid_drop_2, 1977
# Loading: worms, iid_drop_2, 501
# Loading: worms, iid_drop_2, 3263827
# Loading: worms, iid_keep_1, 1138
# Loading: worms, iid_keep_1, 421
# Loading: worms, iid_keep_1, 1313
# Loading: worms, iid_keep_1, 5555
# Loading: worms, iid_keep_1, 6567
# Loading: worms, iid_keep_1, 327
# Loading: worms, iid_keep_1, 2187
# Loading: worms, iid_keep_1, 1977
# Loading: worms, iid_keep_1, 501
# Loading: worms, iid_keep_1, 3263827
# Loading: worms, kmeans_full, 1138
# Loading: worms, kmeans_full, 421
# Loading: worms, kmeans_full, 1313
# Loading: worms, kmeans_full, 5555
# Loading: worms, kmeans_full, 6567
# Loading: worms, kmeans_full, 327
# Loading: worms, kmeans_full, 2187
# Loading: worms, kmeans_full, 1977
# Loading: worms, kmeans_full, 501
# Loading: worms, kmeans_full, 3263827
# Loading: worms, kmeans_drop_1, 1138
# Loading: worms, kmeans_drop_1, 421
# Loading: worms, kmeans_drop_1, 1313
# Loading: worms, kmeans_drop_1, 5555
# Loading: worms, kmeans_drop_1, 6567
# Loading: worms, kmeans_drop_1, 327
# Loading: worms, kmeans_drop_1, 2187
# Loading: worms, kmeans_drop_1, 1977
# Loading: worms, kmeans_drop_1, 501
# Loading: worms, kmeans_drop_1, 3263827
# Loading: worms, kmeans_drop_2, 1138
# Loading: worms, kmeans_drop_2, 421
# Loading: worms, kmeans_drop_2, 1313
# Loading: worms, kmeans_drop_2, 5555
# Loading: worms, kmeans_drop_2, 6567
# Loading: worms, kmeans_drop_2, 327
# Loading: worms, kmeans_drop_2, 2187
# Loading: worms, kmeans_drop_2, 1977
# Loading: worms, kmeans_drop_2, 501
# Loading: worms, kmeans_drop_2, 3263827
# Loading: worms, kmeans_keep_1, 1138
# Loading: worms, kmeans_keep_1, 421
# Loading: worms, kmeans_keep_1, 1313
# Loading: worms, kmeans_keep_1, 5555
# Loading: worms, kmeans_keep_1, 6567
# Loading: worms, kmeans_keep_1, 327
# Loading: worms, kmeans_keep_1, 2187
# Loading: worms, kmeans_keep_1, 1977
# Loading: worms, kmeans_keep_1, 501
# Loading: worms, kmeans_keep_1, 3263827
# Loading: backdoor, iid_full, 1138
# Loading: backdoor, iid_full, 421
# Loading: backdoor, iid_full, 1313
# Loading: backdoor, iid_full, 5555
# Loading: backdoor, iid_full, 6567
# Loading: backdoor, iid_full, 327
# Loading: backdoor, iid_full, 2187
# Loading: backdoor, iid_full, 1977
# Loading: backdoor, iid_full, 501
# Loading: backdoor, iid_full, 3263827
# Loading: backdoor, iid_drop_1, 1138
# Loading: backdoor, iid_drop_1, 421
# Loading: backdoor, iid_drop_1, 1313
# Loading: backdoor, iid_drop_1, 5555
# Loading: backdoor, iid_drop_1, 6567
# Loading: backdoor, iid_drop_1, 327
# Loading: backdoor, iid_drop_1, 2187
# Loading: backdoor, iid_drop_1, 1977
# Loading: backdoor, iid_drop_1, 501
# Loading: backdoor, iid_drop_1, 3263827
# Loading: backdoor, iid_drop_2, 1138
# Loading: backdoor, iid_drop_2, 421
# Loading: backdoor, iid_drop_2, 1313
# Loading: backdoor, iid_drop_2, 5555
# Loading: backdoor, iid_drop_2, 6567
# Loading: backdoor, iid_drop_2, 327
# Loading: backdoor, iid_drop_2, 2187
# Loading: backdoor, iid_drop_2, 1977
# Loading: backdoor, iid_drop_2, 501
# Loading: backdoor, iid_drop_2, 3263827
# Loading: backdoor, iid_keep_1, 1138
# Loading: backdoor, iid_keep_1, 421
# Loading: backdoor, iid_keep_1, 1313
# Loading: backdoor, iid_keep_1, 5555
# Loading: backdoor, iid_keep_1, 6567
# Loading: backdoor, iid_keep_1, 327
# Loading: backdoor, iid_keep_1, 2187
# Loading: backdoor, iid_keep_1, 1977
# Loading: backdoor, iid_keep_1, 501
# Loading: backdoor, iid_keep_1, 3263827
# Loading: backdoor, kmeans_full, 1138
# Loading: backdoor, kmeans_full, 421
# Loading: backdoor, kmeans_full, 1313
# Loading: backdoor, kmeans_full, 5555
# Loading: backdoor, kmeans_full, 6567
# Loading: backdoor, kmeans_full, 327
# Loading: backdoor, kmeans_full, 2187
# Loading: backdoor, kmeans_full, 1977
# Loading: backdoor, kmeans_full, 501
# Loading: backdoor, kmeans_full, 3263827
# Loading: backdoor, kmeans_drop_1, 1138
# Loading: backdoor, kmeans_drop_1, 421
# Loading: backdoor, kmeans_drop_1, 1313
# Loading: backdoor, kmeans_drop_1, 5555
# Loading: backdoor, kmeans_drop_1, 6567
# Loading: backdoor, kmeans_drop_1, 327
# Loading: backdoor, kmeans_drop_1, 2187
# Loading: backdoor, kmeans_drop_1, 1977
# Loading: backdoor, kmeans_drop_1, 501
# Loading: backdoor, kmeans_drop_1, 3263827
# Loading: backdoor, kmeans_drop_2, 1138
# Loading: backdoor, kmeans_drop_2, 421
# Loading: backdoor, kmeans_drop_2, 1313
# Loading: backdoor, kmeans_drop_2, 5555
# Loading: backdoor, kmeans_drop_2, 6567
# Loading: backdoor, kmeans_drop_2, 327
# Loading: backdoor, kmeans_drop_2, 2187
# Loading: backdoor, kmeans_drop_2, 1977
# Loading: backdoor, kmeans_drop_2, 501
# Loading: backdoor, kmeans_drop_2, 3263827
# Loading: backdoor, kmeans_keep_1, 1138
# Loading: backdoor, kmeans_keep_1, 421
# Loading: backdoor, kmeans_keep_1, 1313
# Loading: backdoor, kmeans_keep_1, 5555
# Loading: backdoor, kmeans_keep_1, 6567
# Loading: backdoor, kmeans_keep_1, 327
# Loading: backdoor, kmeans_keep_1, 2187
# Loading: backdoor, kmeans_keep_1, 1977
# Loading: backdoor, kmeans_keep_1, 501
# Loading: backdoor, kmeans_keep_1, 3263827
# Loading: analysis, iid_full, 1138
# Loading: analysis, iid_full, 421
# Loading: analysis, iid_full, 1313
# Loading: analysis, iid_full, 5555
# Loading: analysis, iid_full, 6567
# Loading: analysis, iid_full, 327
# Loading: analysis, iid_full, 2187
# Loading: analysis, iid_full, 1977
# Loading: analysis, iid_full, 501
# Loading: analysis, iid_full, 3263827
# Loading: analysis, iid_drop_1, 1138
# Loading: analysis, iid_drop_1, 421
# Loading: analysis, iid_drop_1, 1313
# Loading: analysis, iid_drop_1, 5555
# Loading: analysis, iid_drop_1, 6567
# Loading: analysis, iid_drop_1, 327
# Loading: analysis, iid_drop_1, 2187
# Loading: analysis, iid_drop_1, 1977
# Loading: analysis, iid_drop_1, 501
# Loading: analysis, iid_drop_1, 3263827
# Loading: analysis, iid_drop_2, 1138
# Loading: analysis, iid_drop_2, 421
# Loading: analysis, iid_drop_2, 1313
# Loading: analysis, iid_drop_2, 5555
# Loading: analysis, iid_drop_2, 6567
# Loading: analysis, iid_drop_2, 327
# Loading: analysis, iid_drop_2, 2187
# Loading: analysis, iid_drop_2, 1977
# Loading: analysis, iid_drop_2, 501
# Loading: analysis, iid_drop_2, 3263827
# Loading: analysis, iid_keep_1, 1138
# Loading: analysis, iid_keep_1, 421
# Loading: analysis, iid_keep_1, 1313
# Loading: analysis, iid_keep_1, 5555
# Loading: analysis, iid_keep_1, 6567
# Loading: analysis, iid_keep_1, 327
# Loading: analysis, iid_keep_1, 2187
# Loading: analysis, iid_keep_1, 1977
# Loading: analysis, iid_keep_1, 501
# Loading: analysis, iid_keep_1, 3263827
# Loading: analysis, kmeans_full, 1138
# Loading: analysis, kmeans_full, 421
# Loading: analysis, kmeans_full, 1313
# Loading: analysis, kmeans_full, 5555
# Loading: analysis, kmeans_full, 6567
# Loading: analysis, kmeans_full, 327
# Loading: analysis, kmeans_full, 2187
# Loading: analysis, kmeans_full, 1977
# Loading: analysis, kmeans_full, 501
# Loading: analysis, kmeans_full, 3263827
# Loading: analysis, kmeans_drop_1, 1138
# Loading: analysis, kmeans_drop_1, 421
# Loading: analysis, kmeans_drop_1, 1313
# Loading: analysis, kmeans_drop_1, 5555
# Loading: analysis, kmeans_drop_1, 6567
# Loading: analysis, kmeans_drop_1, 327
# Loading: analysis, kmeans_drop_1, 2187
# Loading: analysis, kmeans_drop_1, 1977
# Loading: analysis, kmeans_drop_1, 501
# Loading: analysis, kmeans_drop_1, 3263827
# Loading: analysis, kmeans_drop_2, 1138
# Loading: analysis, kmeans_drop_2, 421
# Loading: analysis, kmeans_drop_2, 1313
# Loading: analysis, kmeans_drop_2, 5555
# Loading: analysis, kmeans_drop_2, 6567
# Loading: analysis, kmeans_drop_2, 327
# Loading: analysis, kmeans_drop_2, 2187
# Loading: analysis, kmeans_drop_2, 1977
# Loading: analysis, kmeans_drop_2, 501
# Loading: analysis, kmeans_drop_2, 3263827
# Loading: analysis, kmeans_keep_1, 1138
# Loading: analysis, kmeans_keep_1, 421
# Loading: analysis, kmeans_keep_1, 1313
# Loading: analysis, kmeans_keep_1, 5555
# Loading: analysis, kmeans_keep_1, 6567
# Loading: analysis, kmeans_keep_1, 327
# Loading: analysis, kmeans_keep_1, 2187
# Loading: analysis, kmeans_keep_1, 1977
# Loading: analysis, kmeans_keep_1, 501
# Loading: analysis, kmeans_keep_1, 3263827
# Loaded all gradients

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import NullLocator
from sklearn.discriminant_analysis import StandardScaler

df = grads_df  # [grads_df["Seed"] == 1138]

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[(df["Partitioner"] == partitioner) & (df["Target"] == "untargeted")]

    grads_array = np.array(data["Gradients"].tolist())
    grads_array = StandardScaler().fit_transform(grads_array)
    grads_pca = PCA(n_components=2).fit_transform(grads_array)

    benign = grads_pca[data["Client"].str.contains("benign")]
    ax.scatter(benign[:, 0], benign[:, 1], s=1, c="blue", label="Benign")

    malicious = grads_pca[~data["Client"].str.contains("benign")]
    ax.scatter(malicious[:, 0], malicious[:, 1], s=1, c="red", label="Malicious")

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles,
    labels=labels,
    ncol=2,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.1),
)
fig.suptitle("Gradients in 2D, colored by round")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by round')

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import NullLocator

df = grads_df[grads_df["Round"] == 10]

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[(df["Partitioner"] == partitioner) & (df["Target"] == "untargeted")]

    benign = data[data["Client"].str.contains("benign")]
    ax.scatter(benign["PCA1"], benign["PCA2"], s=1, c="blue", label="Benign")

    malicious = data[~data["Client"].str.contains("benign")]
    ax.scatter(malicious["PCA1"], malicious["PCA2"], s=1, c="red", label="Malicious")

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles,
    labels=labels,
    ncol=2,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.1),
)
fig.suptitle("Gradients in 2D, colored by round")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by round')

# %%
any(grads_df.drop(["Gradients"], axis=1).duplicated())
# Out:
# False

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import NullLocator

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

df = grads_df[
    (grads_df["Target"] != "untargeted")
    & (grads_df["Round"] == 10)
    & (grads_df["Seed"] == 1138)
]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[df["Partitioner"] == partitioner]

    benign = data[data["Client"].str.contains("benign")]
    ax.scatter(
        benign["PCA1"], benign["PCA2"], s=1, color="blue", label="Benign", alpha=0.5
    )

    malicious = data[~data["Client"].str.contains("benign")]
    for label, c in zip(
        ["dos", "ddos", "bot", "bruteforce", "infiltration"],
        ["red", "green", "purple", "orange", "yellow"],
    ):
        target = malicious[malicious["Target"] == label]
        ax.scatter(
            malicious["PCA1"], malicious["PCA2"], s=1, color=c, label=label, alpha=0.5
        )

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles,
    labels=labels,
    ncol=6,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.1),
)
fig.suptitle("Gradients in 2D, colored by malicious target")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by malicious target')

# %% [markdown]
# ### Detectability of similar attacks

# %%
import itertools
from functools import partial
from pathlib import Path

import pandas as pd
from eiffel.analysis.metrics import search_results

searchfn = partial(
    search_results,
    "similarity/results/",
    scenario="continuous-100",
    datasets=".*nb15",
    distribution="5-5",
)

grads_df = pd.DataFrame()

for target, partitioner, seed in itertools.product(
    [
        "untargeted",
        "exploits",
        "reconnaissance",
        "dos",
        "generic",
        "shellcode",
        "fuzzers",
        "worms",
        "backdoor",
        "analysis",
    ],
    [
        "iid_full",
        "iid_drop_1",
        "iid_drop_2",
        "iid_keep_1",
        "kmeans_full",
        "kmeans_drop_1",
        "kmeans_drop_2",
        "kmeans_keep_1",
    ],
    [1138, 421, 1313, 5555, 6567, 327, 2187, 1977, 501, 3263827],
):
    print(f"Loading: {target}, {partitioner}, {seed}")

    paths = searchfn(partitioner=partitioner, target=target, seed=seed)
    assert len(paths) == 1
    path = paths[0]
    part_grads_dfs: list[pd.DataFrame] = [
        pd.read_pickle(p) for p in Path(path).glob("grads*.pkl")
    ]
    assert part_grads_dfs[0].shape[0] == 10  # ten client per partition
    assert len(part_grads_dfs) == 10  # ten clients

    part_grads_df = pd.concat(part_grads_dfs, axis=0, ignore_index=True)
    part_grads_df["Partitioner"] = partitioner
    part_grads_df["Target"] = target
    part_grads_df["Seed"] = seed

    grads_df = pd.concat([grads_df, part_grads_df], axis=0, ignore_index=True)

print("Loaded all gradients")

for seed in [1138, 421, 1313, 5555, 6567, 327, 2187, 1977, 501, 3263827]:
    mask = grads_df["Seed"] == seed
    grads_array = np.array(grads_df.loc[mask, "Gradients"].tolist())
    grads_pca = PCA(n_components=2).fit_transform(grads_array)

    grads_df.loc[mask, "PCA1"] = grads_pca[:, 0]
    grads_df.loc[mask, "PCA2"] = grads_pca[:, 1]

grads_df["Client"] = grads_df["Client"].apply(lambda x: "_".join(x.split("_")[1:]))
# Out:
# Loading: untargeted, iid_full, 1138
# Loading: untargeted, iid_full, 421
# Loading: untargeted, iid_full, 1313
# Loading: untargeted, iid_full, 5555
# Loading: untargeted, iid_full, 6567
# Loading: untargeted, iid_full, 327
# Loading: untargeted, iid_full, 2187
# Loading: untargeted, iid_full, 1977
# Loading: untargeted, iid_full, 501
# Loading: untargeted, iid_full, 3263827
# Loading: untargeted, iid_drop_1, 1138
# Loading: untargeted, iid_drop_1, 421
# Loading: untargeted, iid_drop_1, 1313
# Loading: untargeted, iid_drop_1, 5555
# Loading: untargeted, iid_drop_1, 6567
# Loading: untargeted, iid_drop_1, 327
# Loading: untargeted, iid_drop_1, 2187
# Loading: untargeted, iid_drop_1, 1977
# Loading: untargeted, iid_drop_1, 501
# Loading: untargeted, iid_drop_1, 3263827
# Loading: untargeted, iid_drop_2, 1138
# Loading: untargeted, iid_drop_2, 421
# Loading: untargeted, iid_drop_2, 1313
# Loading: untargeted, iid_drop_2, 5555
# Loading: untargeted, iid_drop_2, 6567
# Loading: untargeted, iid_drop_2, 327
# Loading: untargeted, iid_drop_2, 2187
# Loading: untargeted, iid_drop_2, 1977
# Loading: untargeted, iid_drop_2, 501
# Loading: untargeted, iid_drop_2, 3263827
# Loading: untargeted, iid_keep_1, 1138
# Loading: untargeted, iid_keep_1, 421
# Loading: untargeted, iid_keep_1, 1313
# Loading: untargeted, iid_keep_1, 5555
# Loading: untargeted, iid_keep_1, 6567
# Loading: untargeted, iid_keep_1, 327
# Loading: untargeted, iid_keep_1, 2187
# Loading: untargeted, iid_keep_1, 1977
# Loading: untargeted, iid_keep_1, 501
# Loading: untargeted, iid_keep_1, 3263827
# Loading: untargeted, kmeans_full, 1138
# Loading: untargeted, kmeans_full, 421
# Loading: untargeted, kmeans_full, 1313
# Loading: untargeted, kmeans_full, 5555
# Loading: untargeted, kmeans_full, 6567
# Loading: untargeted, kmeans_full, 327
# Loading: untargeted, kmeans_full, 2187
# Loading: untargeted, kmeans_full, 1977
# Loading: untargeted, kmeans_full, 501
# Loading: untargeted, kmeans_full, 3263827
# Loading: untargeted, kmeans_drop_1, 1138
# Loading: untargeted, kmeans_drop_1, 421
# Loading: untargeted, kmeans_drop_1, 1313
# Loading: untargeted, kmeans_drop_1, 5555
# Loading: untargeted, kmeans_drop_1, 6567
# Loading: untargeted, kmeans_drop_1, 327
# Loading: untargeted, kmeans_drop_1, 2187
# Loading: untargeted, kmeans_drop_1, 1977
# Loading: untargeted, kmeans_drop_1, 501
# Loading: untargeted, kmeans_drop_1, 3263827
# Loading: untargeted, kmeans_drop_2, 1138
# Loading: untargeted, kmeans_drop_2, 421
# Loading: untargeted, kmeans_drop_2, 1313
# Loading: untargeted, kmeans_drop_2, 5555
# Loading: untargeted, kmeans_drop_2, 6567
# Loading: untargeted, kmeans_drop_2, 327
# Loading: untargeted, kmeans_drop_2, 2187
# Loading: untargeted, kmeans_drop_2, 1977
# Loading: untargeted, kmeans_drop_2, 501
# Loading: untargeted, kmeans_drop_2, 3263827
# Loading: untargeted, kmeans_keep_1, 1138
# Loading: untargeted, kmeans_keep_1, 421
# Loading: untargeted, kmeans_keep_1, 1313
# Loading: untargeted, kmeans_keep_1, 5555
# Loading: untargeted, kmeans_keep_1, 6567
# Loading: untargeted, kmeans_keep_1, 327
# Loading: untargeted, kmeans_keep_1, 2187
# Loading: untargeted, kmeans_keep_1, 1977
# Loading: untargeted, kmeans_keep_1, 501
# Loading: untargeted, kmeans_keep_1, 3263827
# Loading: exploits, iid_full, 1138
# Loading: exploits, iid_full, 421
# Loading: exploits, iid_full, 1313
# Loading: exploits, iid_full, 5555
# Loading: exploits, iid_full, 6567
# Loading: exploits, iid_full, 327
# Loading: exploits, iid_full, 2187
# Loading: exploits, iid_full, 1977
# Loading: exploits, iid_full, 501
# Loading: exploits, iid_full, 3263827
# Loading: exploits, iid_drop_1, 1138
# Loading: exploits, iid_drop_1, 421
# Loading: exploits, iid_drop_1, 1313
# Loading: exploits, iid_drop_1, 5555
# Loading: exploits, iid_drop_1, 6567
# Loading: exploits, iid_drop_1, 327
# Loading: exploits, iid_drop_1, 2187
# Loading: exploits, iid_drop_1, 1977
# Loading: exploits, iid_drop_1, 501
# Loading: exploits, iid_drop_1, 3263827
# Loading: exploits, iid_drop_2, 1138
# Loading: exploits, iid_drop_2, 421
# Loading: exploits, iid_drop_2, 1313
# Loading: exploits, iid_drop_2, 5555
# Loading: exploits, iid_drop_2, 6567
# Loading: exploits, iid_drop_2, 327
# Loading: exploits, iid_drop_2, 2187
# Loading: exploits, iid_drop_2, 1977
# Loading: exploits, iid_drop_2, 501
# Loading: exploits, iid_drop_2, 3263827
# Loading: exploits, iid_keep_1, 1138
# Loading: exploits, iid_keep_1, 421
# Loading: exploits, iid_keep_1, 1313
# Loading: exploits, iid_keep_1, 5555
# Loading: exploits, iid_keep_1, 6567
# Loading: exploits, iid_keep_1, 327
# Loading: exploits, iid_keep_1, 2187
# Loading: exploits, iid_keep_1, 1977
# Loading: exploits, iid_keep_1, 501
# Loading: exploits, iid_keep_1, 3263827
# Loading: exploits, kmeans_full, 1138
# Loading: exploits, kmeans_full, 421
# Loading: exploits, kmeans_full, 1313
# Loading: exploits, kmeans_full, 5555
# Loading: exploits, kmeans_full, 6567
# Loading: exploits, kmeans_full, 327
# Loading: exploits, kmeans_full, 2187
# Loading: exploits, kmeans_full, 1977
# Loading: exploits, kmeans_full, 501
# Loading: exploits, kmeans_full, 3263827
# Loading: exploits, kmeans_drop_1, 1138
# Loading: exploits, kmeans_drop_1, 421
# Loading: exploits, kmeans_drop_1, 1313
# Loading: exploits, kmeans_drop_1, 5555
# Loading: exploits, kmeans_drop_1, 6567
# Loading: exploits, kmeans_drop_1, 327
# Loading: exploits, kmeans_drop_1, 2187
# Loading: exploits, kmeans_drop_1, 1977
# Loading: exploits, kmeans_drop_1, 501
# Loading: exploits, kmeans_drop_1, 3263827
# Loading: exploits, kmeans_drop_2, 1138
# Loading: exploits, kmeans_drop_2, 421
# Loading: exploits, kmeans_drop_2, 1313
# Loading: exploits, kmeans_drop_2, 5555
# Loading: exploits, kmeans_drop_2, 6567
# Loading: exploits, kmeans_drop_2, 327
# Loading: exploits, kmeans_drop_2, 2187
# Loading: exploits, kmeans_drop_2, 1977
# Loading: exploits, kmeans_drop_2, 501
# Loading: exploits, kmeans_drop_2, 3263827
# Loading: exploits, kmeans_keep_1, 1138
# Loading: exploits, kmeans_keep_1, 421
# Loading: exploits, kmeans_keep_1, 1313
# Loading: exploits, kmeans_keep_1, 5555
# Loading: exploits, kmeans_keep_1, 6567
# Loading: exploits, kmeans_keep_1, 327
# Loading: exploits, kmeans_keep_1, 2187
# Loading: exploits, kmeans_keep_1, 1977
# Loading: exploits, kmeans_keep_1, 501
# Loading: exploits, kmeans_keep_1, 3263827
# Loading: reconnaissance, iid_full, 1138
# Loading: reconnaissance, iid_full, 421
# Loading: reconnaissance, iid_full, 1313
# Loading: reconnaissance, iid_full, 5555
# Loading: reconnaissance, iid_full, 6567
# Loading: reconnaissance, iid_full, 327
# Loading: reconnaissance, iid_full, 2187
# Loading: reconnaissance, iid_full, 1977
# Loading: reconnaissance, iid_full, 501
# Loading: reconnaissance, iid_full, 3263827
# Loading: reconnaissance, iid_drop_1, 1138
# Loading: reconnaissance, iid_drop_1, 421
# Loading: reconnaissance, iid_drop_1, 1313
# Loading: reconnaissance, iid_drop_1, 5555
# Loading: reconnaissance, iid_drop_1, 6567
# Loading: reconnaissance, iid_drop_1, 327
# Loading: reconnaissance, iid_drop_1, 2187
# Loading: reconnaissance, iid_drop_1, 1977
# Loading: reconnaissance, iid_drop_1, 501
# Loading: reconnaissance, iid_drop_1, 3263827
# Loading: reconnaissance, iid_drop_2, 1138
# Loading: reconnaissance, iid_drop_2, 421
# Loading: reconnaissance, iid_drop_2, 1313
# Loading: reconnaissance, iid_drop_2, 5555
# Loading: reconnaissance, iid_drop_2, 6567
# Loading: reconnaissance, iid_drop_2, 327
# Loading: reconnaissance, iid_drop_2, 2187
# Loading: reconnaissance, iid_drop_2, 1977
# Loading: reconnaissance, iid_drop_2, 501
# Loading: reconnaissance, iid_drop_2, 3263827
# Loading: reconnaissance, iid_keep_1, 1138
# Loading: reconnaissance, iid_keep_1, 421
# Loading: reconnaissance, iid_keep_1, 1313
# Loading: reconnaissance, iid_keep_1, 5555
# Loading: reconnaissance, iid_keep_1, 6567
# Loading: reconnaissance, iid_keep_1, 327
# Loading: reconnaissance, iid_keep_1, 2187
# Loading: reconnaissance, iid_keep_1, 1977
# Loading: reconnaissance, iid_keep_1, 501
# Loading: reconnaissance, iid_keep_1, 3263827
# Loading: reconnaissance, kmeans_full, 1138
# Loading: reconnaissance, kmeans_full, 421
# Loading: reconnaissance, kmeans_full, 1313
# Loading: reconnaissance, kmeans_full, 5555
# Loading: reconnaissance, kmeans_full, 6567
# Loading: reconnaissance, kmeans_full, 327
# Loading: reconnaissance, kmeans_full, 2187
# Loading: reconnaissance, kmeans_full, 1977
# Loading: reconnaissance, kmeans_full, 501
# Loading: reconnaissance, kmeans_full, 3263827
# Loading: reconnaissance, kmeans_drop_1, 1138
# Loading: reconnaissance, kmeans_drop_1, 421
# Loading: reconnaissance, kmeans_drop_1, 1313
# Loading: reconnaissance, kmeans_drop_1, 5555
# Loading: reconnaissance, kmeans_drop_1, 6567
# Loading: reconnaissance, kmeans_drop_1, 327
# Loading: reconnaissance, kmeans_drop_1, 2187
# Loading: reconnaissance, kmeans_drop_1, 1977
# Loading: reconnaissance, kmeans_drop_1, 501
# Loading: reconnaissance, kmeans_drop_1, 3263827
# Loading: reconnaissance, kmeans_drop_2, 1138
# Loading: reconnaissance, kmeans_drop_2, 421
# Loading: reconnaissance, kmeans_drop_2, 1313
# Loading: reconnaissance, kmeans_drop_2, 5555
# Loading: reconnaissance, kmeans_drop_2, 6567
# Loading: reconnaissance, kmeans_drop_2, 327
# Loading: reconnaissance, kmeans_drop_2, 2187
# Loading: reconnaissance, kmeans_drop_2, 1977
# Loading: reconnaissance, kmeans_drop_2, 501
# Loading: reconnaissance, kmeans_drop_2, 3263827
# Loading: reconnaissance, kmeans_keep_1, 1138
# Loading: reconnaissance, kmeans_keep_1, 421
# Loading: reconnaissance, kmeans_keep_1, 1313
# Loading: reconnaissance, kmeans_keep_1, 5555
# Loading: reconnaissance, kmeans_keep_1, 6567
# Loading: reconnaissance, kmeans_keep_1, 327
# Loading: reconnaissance, kmeans_keep_1, 2187
# Loading: reconnaissance, kmeans_keep_1, 1977
# Loading: reconnaissance, kmeans_keep_1, 501
# Loading: reconnaissance, kmeans_keep_1, 3263827
# Loading: dos, iid_full, 1138
# Loading: dos, iid_full, 421
# Loading: dos, iid_full, 1313
# Loading: dos, iid_full, 5555
# Loading: dos, iid_full, 6567
# Loading: dos, iid_full, 327
# Loading: dos, iid_full, 2187
# Loading: dos, iid_full, 1977
# Loading: dos, iid_full, 501
# Loading: dos, iid_full, 3263827
# Loading: dos, iid_drop_1, 1138
# Loading: dos, iid_drop_1, 421
# Loading: dos, iid_drop_1, 1313
# Loading: dos, iid_drop_1, 5555
# Loading: dos, iid_drop_1, 6567
# Loading: dos, iid_drop_1, 327
# Loading: dos, iid_drop_1, 2187
# Loading: dos, iid_drop_1, 1977
# Loading: dos, iid_drop_1, 501
# Loading: dos, iid_drop_1, 3263827
# Loading: dos, iid_drop_2, 1138
# Loading: dos, iid_drop_2, 421
# Loading: dos, iid_drop_2, 1313
# Loading: dos, iid_drop_2, 5555
# Loading: dos, iid_drop_2, 6567
# Loading: dos, iid_drop_2, 327
# Loading: dos, iid_drop_2, 2187
# Loading: dos, iid_drop_2, 1977
# Loading: dos, iid_drop_2, 501
# Loading: dos, iid_drop_2, 3263827
# Loading: dos, iid_keep_1, 1138
# Loading: dos, iid_keep_1, 421
# Loading: dos, iid_keep_1, 1313
# Loading: dos, iid_keep_1, 5555
# Loading: dos, iid_keep_1, 6567
# Loading: dos, iid_keep_1, 327
# Loading: dos, iid_keep_1, 2187
# Loading: dos, iid_keep_1, 1977
# Loading: dos, iid_keep_1, 501
# Loading: dos, iid_keep_1, 3263827
# Loading: dos, kmeans_full, 1138
# Loading: dos, kmeans_full, 421
# Loading: dos, kmeans_full, 1313
# Loading: dos, kmeans_full, 5555
# Loading: dos, kmeans_full, 6567
# Loading: dos, kmeans_full, 327
# Loading: dos, kmeans_full, 2187
# Loading: dos, kmeans_full, 1977
# Loading: dos, kmeans_full, 501
# Loading: dos, kmeans_full, 3263827
# Loading: dos, kmeans_drop_1, 1138
# Loading: dos, kmeans_drop_1, 421
# Loading: dos, kmeans_drop_1, 1313
# Loading: dos, kmeans_drop_1, 5555
# Loading: dos, kmeans_drop_1, 6567
# Loading: dos, kmeans_drop_1, 327
# Loading: dos, kmeans_drop_1, 2187
# Loading: dos, kmeans_drop_1, 1977
# Loading: dos, kmeans_drop_1, 501
# Loading: dos, kmeans_drop_1, 3263827
# Loading: dos, kmeans_drop_2, 1138
# Loading: dos, kmeans_drop_2, 421
# Loading: dos, kmeans_drop_2, 1313
# Loading: dos, kmeans_drop_2, 5555
# Loading: dos, kmeans_drop_2, 6567
# Loading: dos, kmeans_drop_2, 327
# Loading: dos, kmeans_drop_2, 2187
# Loading: dos, kmeans_drop_2, 1977
# Loading: dos, kmeans_drop_2, 501
# Loading: dos, kmeans_drop_2, 3263827
# Loading: dos, kmeans_keep_1, 1138
# Loading: dos, kmeans_keep_1, 421
# Loading: dos, kmeans_keep_1, 1313
# Loading: dos, kmeans_keep_1, 5555
# Loading: dos, kmeans_keep_1, 6567
# Loading: dos, kmeans_keep_1, 327
# Loading: dos, kmeans_keep_1, 2187
# Loading: dos, kmeans_keep_1, 1977
# Loading: dos, kmeans_keep_1, 501
# Loading: dos, kmeans_keep_1, 3263827
# Loading: generic, iid_full, 1138
# Loading: generic, iid_full, 421
# Loading: generic, iid_full, 1313
# Loading: generic, iid_full, 5555
# Loading: generic, iid_full, 6567
# Loading: generic, iid_full, 327
# Loading: generic, iid_full, 2187
# Loading: generic, iid_full, 1977
# Loading: generic, iid_full, 501
# Loading: generic, iid_full, 3263827
# Loading: generic, iid_drop_1, 1138
# Loading: generic, iid_drop_1, 421
# Loading: generic, iid_drop_1, 1313
# Loading: generic, iid_drop_1, 5555
# Loading: generic, iid_drop_1, 6567
# Loading: generic, iid_drop_1, 327
# Loading: generic, iid_drop_1, 2187
# Loading: generic, iid_drop_1, 1977
# Loading: generic, iid_drop_1, 501
# Loading: generic, iid_drop_1, 3263827
# Loading: generic, iid_drop_2, 1138
# Loading: generic, iid_drop_2, 421
# Loading: generic, iid_drop_2, 1313
# Loading: generic, iid_drop_2, 5555
# Loading: generic, iid_drop_2, 6567
# Loading: generic, iid_drop_2, 327
# Loading: generic, iid_drop_2, 2187
# Loading: generic, iid_drop_2, 1977
# Loading: generic, iid_drop_2, 501
# Loading: generic, iid_drop_2, 3263827
# Loading: generic, iid_keep_1, 1138
# Loading: generic, iid_keep_1, 421
# Loading: generic, iid_keep_1, 1313
# Loading: generic, iid_keep_1, 5555
# Loading: generic, iid_keep_1, 6567
# Loading: generic, iid_keep_1, 327
# Loading: generic, iid_keep_1, 2187
# Loading: generic, iid_keep_1, 1977
# Loading: generic, iid_keep_1, 501
# Loading: generic, iid_keep_1, 3263827
# Loading: generic, kmeans_full, 1138
# Loading: generic, kmeans_full, 421
# Loading: generic, kmeans_full, 1313
# Loading: generic, kmeans_full, 5555
# Loading: generic, kmeans_full, 6567
# Loading: generic, kmeans_full, 327
# Loading: generic, kmeans_full, 2187
# Loading: generic, kmeans_full, 1977
# Loading: generic, kmeans_full, 501
# Loading: generic, kmeans_full, 3263827
# Loading: generic, kmeans_drop_1, 1138
# Loading: generic, kmeans_drop_1, 421
# Loading: generic, kmeans_drop_1, 1313
# Loading: generic, kmeans_drop_1, 5555
# Loading: generic, kmeans_drop_1, 6567
# Loading: generic, kmeans_drop_1, 327
# Loading: generic, kmeans_drop_1, 2187
# Loading: generic, kmeans_drop_1, 1977
# Loading: generic, kmeans_drop_1, 501
# Loading: generic, kmeans_drop_1, 3263827
# Loading: generic, kmeans_drop_2, 1138
# Loading: generic, kmeans_drop_2, 421
# Loading: generic, kmeans_drop_2, 1313
# Loading: generic, kmeans_drop_2, 5555
# Loading: generic, kmeans_drop_2, 6567
# Loading: generic, kmeans_drop_2, 327
# Loading: generic, kmeans_drop_2, 2187
# Loading: generic, kmeans_drop_2, 1977
# Loading: generic, kmeans_drop_2, 501
# Loading: generic, kmeans_drop_2, 3263827
# Loading: generic, kmeans_keep_1, 1138
# Loading: generic, kmeans_keep_1, 421
# Loading: generic, kmeans_keep_1, 1313
# Loading: generic, kmeans_keep_1, 5555
# Loading: generic, kmeans_keep_1, 6567
# Loading: generic, kmeans_keep_1, 327
# Loading: generic, kmeans_keep_1, 2187
# Loading: generic, kmeans_keep_1, 1977
# Loading: generic, kmeans_keep_1, 501
# Loading: generic, kmeans_keep_1, 3263827
# Loading: shellcode, iid_full, 1138
# Loading: shellcode, iid_full, 421
# Loading: shellcode, iid_full, 1313
# Loading: shellcode, iid_full, 5555
# Loading: shellcode, iid_full, 6567
# Loading: shellcode, iid_full, 327
# Loading: shellcode, iid_full, 2187
# Loading: shellcode, iid_full, 1977
# Loading: shellcode, iid_full, 501
# Loading: shellcode, iid_full, 3263827
# Loading: shellcode, iid_drop_1, 1138
# Loading: shellcode, iid_drop_1, 421
# Loading: shellcode, iid_drop_1, 1313
# Loading: shellcode, iid_drop_1, 5555
# Loading: shellcode, iid_drop_1, 6567
# Loading: shellcode, iid_drop_1, 327
# Loading: shellcode, iid_drop_1, 2187
# Loading: shellcode, iid_drop_1, 1977
# Loading: shellcode, iid_drop_1, 501
# Loading: shellcode, iid_drop_1, 3263827
# Loading: shellcode, iid_drop_2, 1138
# Loading: shellcode, iid_drop_2, 421
# Loading: shellcode, iid_drop_2, 1313
# Loading: shellcode, iid_drop_2, 5555
# Loading: shellcode, iid_drop_2, 6567
# Loading: shellcode, iid_drop_2, 327
# Loading: shellcode, iid_drop_2, 2187
# Loading: shellcode, iid_drop_2, 1977
# Loading: shellcode, iid_drop_2, 501
# Loading: shellcode, iid_drop_2, 3263827
# Loading: shellcode, iid_keep_1, 1138
# Loading: shellcode, iid_keep_1, 421
# Loading: shellcode, iid_keep_1, 1313
# Loading: shellcode, iid_keep_1, 5555
# Loading: shellcode, iid_keep_1, 6567
# Loading: shellcode, iid_keep_1, 327
# Loading: shellcode, iid_keep_1, 2187
# Loading: shellcode, iid_keep_1, 1977
# Loading: shellcode, iid_keep_1, 501
# Loading: shellcode, iid_keep_1, 3263827
# Loading: shellcode, kmeans_full, 1138
# Loading: shellcode, kmeans_full, 421
# Loading: shellcode, kmeans_full, 1313
# Loading: shellcode, kmeans_full, 5555
# Loading: shellcode, kmeans_full, 6567
# Loading: shellcode, kmeans_full, 327
# Loading: shellcode, kmeans_full, 2187
# Loading: shellcode, kmeans_full, 1977
# Loading: shellcode, kmeans_full, 501
# Loading: shellcode, kmeans_full, 3263827
# Loading: shellcode, kmeans_drop_1, 1138
# Loading: shellcode, kmeans_drop_1, 421
# Loading: shellcode, kmeans_drop_1, 1313
# Loading: shellcode, kmeans_drop_1, 5555
# Loading: shellcode, kmeans_drop_1, 6567
# Loading: shellcode, kmeans_drop_1, 327
# Loading: shellcode, kmeans_drop_1, 2187
# Loading: shellcode, kmeans_drop_1, 1977
# Loading: shellcode, kmeans_drop_1, 501
# Loading: shellcode, kmeans_drop_1, 3263827
# Loading: shellcode, kmeans_drop_2, 1138
# Loading: shellcode, kmeans_drop_2, 421
# Loading: shellcode, kmeans_drop_2, 1313
# Loading: shellcode, kmeans_drop_2, 5555
# Loading: shellcode, kmeans_drop_2, 6567
# Loading: shellcode, kmeans_drop_2, 327
# Loading: shellcode, kmeans_drop_2, 2187
# Loading: shellcode, kmeans_drop_2, 1977
# Loading: shellcode, kmeans_drop_2, 501
# Loading: shellcode, kmeans_drop_2, 3263827
# Loading: shellcode, kmeans_keep_1, 1138
# Loading: shellcode, kmeans_keep_1, 421
# Loading: shellcode, kmeans_keep_1, 1313
# Loading: shellcode, kmeans_keep_1, 5555
# Loading: shellcode, kmeans_keep_1, 6567
# Loading: shellcode, kmeans_keep_1, 327
# Loading: shellcode, kmeans_keep_1, 2187
# Loading: shellcode, kmeans_keep_1, 1977
# Loading: shellcode, kmeans_keep_1, 501
# Loading: shellcode, kmeans_keep_1, 3263827
# Loading: fuzzers, iid_full, 1138
# Loading: fuzzers, iid_full, 421
# Loading: fuzzers, iid_full, 1313
# Loading: fuzzers, iid_full, 5555
# Loading: fuzzers, iid_full, 6567
# Loading: fuzzers, iid_full, 327
# Loading: fuzzers, iid_full, 2187
# Loading: fuzzers, iid_full, 1977
# Loading: fuzzers, iid_full, 501
# Loading: fuzzers, iid_full, 3263827
# Loading: fuzzers, iid_drop_1, 1138
# Loading: fuzzers, iid_drop_1, 421
# Loading: fuzzers, iid_drop_1, 1313
# Loading: fuzzers, iid_drop_1, 5555
# Loading: fuzzers, iid_drop_1, 6567
# Loading: fuzzers, iid_drop_1, 327
# Loading: fuzzers, iid_drop_1, 2187
# Loading: fuzzers, iid_drop_1, 1977
# Loading: fuzzers, iid_drop_1, 501
# Loading: fuzzers, iid_drop_1, 3263827
# Loading: fuzzers, iid_drop_2, 1138
# Loading: fuzzers, iid_drop_2, 421
# Loading: fuzzers, iid_drop_2, 1313
# Loading: fuzzers, iid_drop_2, 5555
# Loading: fuzzers, iid_drop_2, 6567
# Loading: fuzzers, iid_drop_2, 327
# Loading: fuzzers, iid_drop_2, 2187
# Loading: fuzzers, iid_drop_2, 1977
# Loading: fuzzers, iid_drop_2, 501
# Loading: fuzzers, iid_drop_2, 3263827
# Loading: fuzzers, iid_keep_1, 1138
# Loading: fuzzers, iid_keep_1, 421
# Loading: fuzzers, iid_keep_1, 1313
# Loading: fuzzers, iid_keep_1, 5555
# Loading: fuzzers, iid_keep_1, 6567
# Loading: fuzzers, iid_keep_1, 327
# Loading: fuzzers, iid_keep_1, 2187
# Loading: fuzzers, iid_keep_1, 1977
# Loading: fuzzers, iid_keep_1, 501
# Loading: fuzzers, iid_keep_1, 3263827
# Loading: fuzzers, kmeans_full, 1138
# Loading: fuzzers, kmeans_full, 421
# Loading: fuzzers, kmeans_full, 1313
# Loading: fuzzers, kmeans_full, 5555
# Loading: fuzzers, kmeans_full, 6567
# Loading: fuzzers, kmeans_full, 327
# Loading: fuzzers, kmeans_full, 2187
# Loading: fuzzers, kmeans_full, 1977
# Loading: fuzzers, kmeans_full, 501
# Loading: fuzzers, kmeans_full, 3263827
# Loading: fuzzers, kmeans_drop_1, 1138
# Loading: fuzzers, kmeans_drop_1, 421
# Loading: fuzzers, kmeans_drop_1, 1313
# Loading: fuzzers, kmeans_drop_1, 5555
# Loading: fuzzers, kmeans_drop_1, 6567
# Loading: fuzzers, kmeans_drop_1, 327
# Loading: fuzzers, kmeans_drop_1, 2187
# Loading: fuzzers, kmeans_drop_1, 1977
# Loading: fuzzers, kmeans_drop_1, 501
# Loading: fuzzers, kmeans_drop_1, 3263827
# Loading: fuzzers, kmeans_drop_2, 1138
# Loading: fuzzers, kmeans_drop_2, 421
# Loading: fuzzers, kmeans_drop_2, 1313
# Loading: fuzzers, kmeans_drop_2, 5555
# Loading: fuzzers, kmeans_drop_2, 6567
# Loading: fuzzers, kmeans_drop_2, 327
# Loading: fuzzers, kmeans_drop_2, 2187
# Loading: fuzzers, kmeans_drop_2, 1977
# Loading: fuzzers, kmeans_drop_2, 501
# Loading: fuzzers, kmeans_drop_2, 3263827
# Loading: fuzzers, kmeans_keep_1, 1138
# Loading: fuzzers, kmeans_keep_1, 421
# Loading: fuzzers, kmeans_keep_1, 1313
# Loading: fuzzers, kmeans_keep_1, 5555
# Loading: fuzzers, kmeans_keep_1, 6567
# Loading: fuzzers, kmeans_keep_1, 327
# Loading: fuzzers, kmeans_keep_1, 2187
# Loading: fuzzers, kmeans_keep_1, 1977
# Loading: fuzzers, kmeans_keep_1, 501
# Loading: fuzzers, kmeans_keep_1, 3263827
# Loading: worms, iid_full, 1138
# Loading: worms, iid_full, 421
# Loading: worms, iid_full, 1313
# Loading: worms, iid_full, 5555
# Loading: worms, iid_full, 6567
# Loading: worms, iid_full, 327
# Loading: worms, iid_full, 2187
# Loading: worms, iid_full, 1977
# Loading: worms, iid_full, 501
# Loading: worms, iid_full, 3263827
# Loading: worms, iid_drop_1, 1138
# Loading: worms, iid_drop_1, 421
# Loading: worms, iid_drop_1, 1313
# Loading: worms, iid_drop_1, 5555
# Loading: worms, iid_drop_1, 6567
# Loading: worms, iid_drop_1, 327
# Loading: worms, iid_drop_1, 2187
# Loading: worms, iid_drop_1, 1977
# Loading: worms, iid_drop_1, 501
# Loading: worms, iid_drop_1, 3263827
# Loading: worms, iid_drop_2, 1138
# Loading: worms, iid_drop_2, 421
# Loading: worms, iid_drop_2, 1313
# Loading: worms, iid_drop_2, 5555
# Loading: worms, iid_drop_2, 6567
# Loading: worms, iid_drop_2, 327
# Loading: worms, iid_drop_2, 2187
# Loading: worms, iid_drop_2, 1977
# Loading: worms, iid_drop_2, 501
# Loading: worms, iid_drop_2, 3263827
# Loading: worms, iid_keep_1, 1138
# Loading: worms, iid_keep_1, 421
# Loading: worms, iid_keep_1, 1313
# Loading: worms, iid_keep_1, 5555
# Loading: worms, iid_keep_1, 6567
# Loading: worms, iid_keep_1, 327
# Loading: worms, iid_keep_1, 2187
# Loading: worms, iid_keep_1, 1977
# Loading: worms, iid_keep_1, 501
# Loading: worms, iid_keep_1, 3263827
# Loading: worms, kmeans_full, 1138
# Loading: worms, kmeans_full, 421
# Loading: worms, kmeans_full, 1313
# Loading: worms, kmeans_full, 5555
# Loading: worms, kmeans_full, 6567
# Loading: worms, kmeans_full, 327
# Loading: worms, kmeans_full, 2187
# Loading: worms, kmeans_full, 1977
# Loading: worms, kmeans_full, 501
# Loading: worms, kmeans_full, 3263827
# Loading: worms, kmeans_drop_1, 1138
# Loading: worms, kmeans_drop_1, 421
# Loading: worms, kmeans_drop_1, 1313
# Loading: worms, kmeans_drop_1, 5555
# Loading: worms, kmeans_drop_1, 6567
# Loading: worms, kmeans_drop_1, 327
# Loading: worms, kmeans_drop_1, 2187
# Loading: worms, kmeans_drop_1, 1977
# Loading: worms, kmeans_drop_1, 501
# Loading: worms, kmeans_drop_1, 3263827
# Loading: worms, kmeans_drop_2, 1138
# Loading: worms, kmeans_drop_2, 421
# Loading: worms, kmeans_drop_2, 1313
# Loading: worms, kmeans_drop_2, 5555
# Loading: worms, kmeans_drop_2, 6567
# Loading: worms, kmeans_drop_2, 327
# Loading: worms, kmeans_drop_2, 2187
# Loading: worms, kmeans_drop_2, 1977
# Loading: worms, kmeans_drop_2, 501
# Loading: worms, kmeans_drop_2, 3263827
# Loading: worms, kmeans_keep_1, 1138
# Loading: worms, kmeans_keep_1, 421
# Loading: worms, kmeans_keep_1, 1313
# Loading: worms, kmeans_keep_1, 5555
# Loading: worms, kmeans_keep_1, 6567
# Loading: worms, kmeans_keep_1, 327
# Loading: worms, kmeans_keep_1, 2187
# Loading: worms, kmeans_keep_1, 1977
# Loading: worms, kmeans_keep_1, 501
# Loading: worms, kmeans_keep_1, 3263827
# Loading: backdoor, iid_full, 1138
# Loading: backdoor, iid_full, 421
# Loading: backdoor, iid_full, 1313
# Loading: backdoor, iid_full, 5555
# Loading: backdoor, iid_full, 6567
# Loading: backdoor, iid_full, 327
# Loading: backdoor, iid_full, 2187
# Loading: backdoor, iid_full, 1977
# Loading: backdoor, iid_full, 501
# Loading: backdoor, iid_full, 3263827
# Loading: backdoor, iid_drop_1, 1138
# Loading: backdoor, iid_drop_1, 421
# Loading: backdoor, iid_drop_1, 1313
# Loading: backdoor, iid_drop_1, 5555
# Loading: backdoor, iid_drop_1, 6567
# Loading: backdoor, iid_drop_1, 327
# Loading: backdoor, iid_drop_1, 2187
# Loading: backdoor, iid_drop_1, 1977
# Loading: backdoor, iid_drop_1, 501
# Loading: backdoor, iid_drop_1, 3263827
# Loading: backdoor, iid_drop_2, 1138
# Loading: backdoor, iid_drop_2, 421
# Loading: backdoor, iid_drop_2, 1313
# Loading: backdoor, iid_drop_2, 5555
# Loading: backdoor, iid_drop_2, 6567
# Loading: backdoor, iid_drop_2, 327
# Loading: backdoor, iid_drop_2, 2187
# Loading: backdoor, iid_drop_2, 1977
# Loading: backdoor, iid_drop_2, 501
# Loading: backdoor, iid_drop_2, 3263827
# Loading: backdoor, iid_keep_1, 1138
# Loading: backdoor, iid_keep_1, 421
# Loading: backdoor, iid_keep_1, 1313
# Loading: backdoor, iid_keep_1, 5555
# Loading: backdoor, iid_keep_1, 6567
# Loading: backdoor, iid_keep_1, 327
# Loading: backdoor, iid_keep_1, 2187
# Loading: backdoor, iid_keep_1, 1977
# Loading: backdoor, iid_keep_1, 501
# Loading: backdoor, iid_keep_1, 3263827
# Loading: backdoor, kmeans_full, 1138
# Loading: backdoor, kmeans_full, 421
# Loading: backdoor, kmeans_full, 1313
# Loading: backdoor, kmeans_full, 5555
# Loading: backdoor, kmeans_full, 6567
# Loading: backdoor, kmeans_full, 327
# Loading: backdoor, kmeans_full, 2187
# Loading: backdoor, kmeans_full, 1977
# Loading: backdoor, kmeans_full, 501
# Loading: backdoor, kmeans_full, 3263827
# Loading: backdoor, kmeans_drop_1, 1138
# Loading: backdoor, kmeans_drop_1, 421
# Loading: backdoor, kmeans_drop_1, 1313
# Loading: backdoor, kmeans_drop_1, 5555
# Loading: backdoor, kmeans_drop_1, 6567
# Loading: backdoor, kmeans_drop_1, 327
# Loading: backdoor, kmeans_drop_1, 2187
# Loading: backdoor, kmeans_drop_1, 1977
# Loading: backdoor, kmeans_drop_1, 501
# Loading: backdoor, kmeans_drop_1, 3263827
# Loading: backdoor, kmeans_drop_2, 1138
# Loading: backdoor, kmeans_drop_2, 421
# Loading: backdoor, kmeans_drop_2, 1313
# Loading: backdoor, kmeans_drop_2, 5555
# Loading: backdoor, kmeans_drop_2, 6567
# Loading: backdoor, kmeans_drop_2, 327
# Loading: backdoor, kmeans_drop_2, 2187
# Loading: backdoor, kmeans_drop_2, 1977
# Loading: backdoor, kmeans_drop_2, 501
# Loading: backdoor, kmeans_drop_2, 3263827
# Loading: backdoor, kmeans_keep_1, 1138
# Loading: backdoor, kmeans_keep_1, 421
# Loading: backdoor, kmeans_keep_1, 1313
# Loading: backdoor, kmeans_keep_1, 5555
# Loading: backdoor, kmeans_keep_1, 6567
# Loading: backdoor, kmeans_keep_1, 327
# Loading: backdoor, kmeans_keep_1, 2187
# Loading: backdoor, kmeans_keep_1, 1977
# Loading: backdoor, kmeans_keep_1, 501
# Loading: backdoor, kmeans_keep_1, 3263827
# Loading: analysis, iid_full, 1138
# Loading: analysis, iid_full, 421
# Loading: analysis, iid_full, 1313
# Loading: analysis, iid_full, 5555
# Loading: analysis, iid_full, 6567
# Loading: analysis, iid_full, 327
# Loading: analysis, iid_full, 2187
# Loading: analysis, iid_full, 1977
# Loading: analysis, iid_full, 501
# Loading: analysis, iid_full, 3263827
# Loading: analysis, iid_drop_1, 1138
# Loading: analysis, iid_drop_1, 421
# Loading: analysis, iid_drop_1, 1313
# Loading: analysis, iid_drop_1, 5555
# Loading: analysis, iid_drop_1, 6567
# Loading: analysis, iid_drop_1, 327
# Loading: analysis, iid_drop_1, 2187
# Loading: analysis, iid_drop_1, 1977
# Loading: analysis, iid_drop_1, 501
# Loading: analysis, iid_drop_1, 3263827
# Loading: analysis, iid_drop_2, 1138
# Loading: analysis, iid_drop_2, 421
# Loading: analysis, iid_drop_2, 1313
# Loading: analysis, iid_drop_2, 5555
# Loading: analysis, iid_drop_2, 6567
# Loading: analysis, iid_drop_2, 327
# Loading: analysis, iid_drop_2, 2187
# Loading: analysis, iid_drop_2, 1977
# Loading: analysis, iid_drop_2, 501
# Loading: analysis, iid_drop_2, 3263827
# Loading: analysis, iid_keep_1, 1138
# Loading: analysis, iid_keep_1, 421
# Loading: analysis, iid_keep_1, 1313
# Loading: analysis, iid_keep_1, 5555
# Loading: analysis, iid_keep_1, 6567
# Loading: analysis, iid_keep_1, 327
# Loading: analysis, iid_keep_1, 2187
# Loading: analysis, iid_keep_1, 1977
# Loading: analysis, iid_keep_1, 501
# Loading: analysis, iid_keep_1, 3263827
# Loading: analysis, kmeans_full, 1138
# Loading: analysis, kmeans_full, 421
# Loading: analysis, kmeans_full, 1313
# Loading: analysis, kmeans_full, 5555
# Loading: analysis, kmeans_full, 6567
# Loading: analysis, kmeans_full, 327
# Loading: analysis, kmeans_full, 2187
# Loading: analysis, kmeans_full, 1977
# Loading: analysis, kmeans_full, 501
# Loading: analysis, kmeans_full, 3263827
# Loading: analysis, kmeans_drop_1, 1138
# Loading: analysis, kmeans_drop_1, 421
# Loading: analysis, kmeans_drop_1, 1313
# Loading: analysis, kmeans_drop_1, 5555
# Loading: analysis, kmeans_drop_1, 6567
# Loading: analysis, kmeans_drop_1, 327
# Loading: analysis, kmeans_drop_1, 2187
# Loading: analysis, kmeans_drop_1, 1977
# Loading: analysis, kmeans_drop_1, 501
# Loading: analysis, kmeans_drop_1, 3263827
# Loading: analysis, kmeans_drop_2, 1138
# Loading: analysis, kmeans_drop_2, 421
# Loading: analysis, kmeans_drop_2, 1313
# Loading: analysis, kmeans_drop_2, 5555
# Loading: analysis, kmeans_drop_2, 6567
# Loading: analysis, kmeans_drop_2, 327
# Loading: analysis, kmeans_drop_2, 2187
# Loading: analysis, kmeans_drop_2, 1977
# Loading: analysis, kmeans_drop_2, 501
# Loading: analysis, kmeans_drop_2, 3263827
# Loading: analysis, kmeans_keep_1, 1138
# Loading: analysis, kmeans_keep_1, 421
# Loading: analysis, kmeans_keep_1, 1313
# Loading: analysis, kmeans_keep_1, 5555
# Loading: analysis, kmeans_keep_1, 6567
# Loading: analysis, kmeans_keep_1, 327
# Loading: analysis, kmeans_keep_1, 2187
# Loading: analysis, kmeans_keep_1, 1977
# Loading: analysis, kmeans_keep_1, 501
# Loading: analysis, kmeans_keep_1, 3263827
# Loaded all gradients

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import NullLocator

df = grads_df  # [grads_df["Round"] == 10]

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[(df["Partitioner"] == partitioner) & (df["Target"] == "untargeted")]

    benign = data[data["Client"].str.contains("benign")]
    ax.scatter(benign["PCA1"], benign["PCA2"], s=1, c="blue", label="Benign")

    malicious = data[~data["Client"].str.contains("benign")]
    ax.scatter(malicious["PCA1"], malicious["PCA2"], s=1, c="red", label="Malicious")

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles,
    labels=labels,
    ncol=2,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.1),
)
fig.suptitle("Gradients in 2D, colored by round")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by round')

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import NullLocator

fig, axs = plt.subplots(
    2,
    4,
    figsize=figsize(1, 0.5, two_column=True),
    constrained_layout=True,
    sharex=True,
    sharey=True,
)

df = grads_df[
    (grads_df["Target"] != "untargeted")
    # & (grads_df["Round"] == 10)
    & (grads_df["Seed"] == 1138)
]

for ax, partitioner in zip(axs.ravel(), df["Partitioner"].unique()):
    # figure setup
    ax.set_title(partitioner, pad=-10)
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    data = df[df["Partitioner"] == partitioner]

    benign = data[data["Client"].str.contains("benign")]
    ax.scatter(
        benign["PCA1"], benign["PCA2"], s=1, color="blue", label="Benign", alpha=0.5
    )

    malicious = data[~data["Client"].str.contains("benign")]
    for label, c in zip(
        ["exploits", "reconnaissance", "dos", "generic", "shellcode", "fuzzers", "worms", "backdoor", "analysis"],
        ["red", "green", "purple", "orange", "yellow", "brown", "pink", "gray", "cyan"],
    ):
        target = malicious[malicious["Target"] == label]
        ax.scatter(
            malicious["PCA1"], malicious["PCA2"], s=1, color=c, label=label, alpha=0.5
        )

handles, labels = axs.ravel()[-1].get_legend_handles_labels()
lgd = fig.legend(
    handles=handles,
    labels=labels,
    ncol=6,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.1),
)
fig.suptitle("Gradients in 2D, colored by malicious target")
# Out:
# Text(0.5, 0.98, 'Gradients in 2D, colored by malicious target')
